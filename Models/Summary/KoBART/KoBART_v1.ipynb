# %% [markdown]
# ### 0. 라이브러리

# %%
import os

# OS 충돌 방지
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# Matplotlib 커널 종료 방지
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# 라이브러리
import warnings
warnings.filterwarnings('ignore')

import time
import random
import pickle

import pandas as pd
import numpy as np

from tqdm import tqdm

import torch
from transformers import PreTrainedTokenizerFast
from transformers import BartForConditionalGeneration

# %%
# 시드 고정
def fixSEED(seed, deterministic=True):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    if deterministic:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

seed = 42
fixSEED(seed=seed)

# %%
dir = '/Summary'
path = '/Users/leesanghyuk/Python_Programs/Projects/Models/' + dir
os.chdir(path)
print('Current Directory:', os.getcwd())
# Out:
# Current Directory: /Users/leesanghyuk/Python_Programs/Projects/Models/Summary

# %%
# GPU 사용 여부 확인
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
# 학습 시작 전 GPU 메모리 확인
def checkGPU(empty=False):
    if torch.cuda.is_available():
        total_mem = torch.cuda.get_device_properties(0).total_memory
        current_mem = torch.cuda.memory_allocated(0)
        free_mem = total_mem - current_mem
        
        print(f'남은 GPU 메모리: {free_mem / (1024 ** 3):.2f} GB')
        
        if empty:
            torch.cuda.empty_cache()
            after_mem = torch.cuda.memory_allocated(0)
            print(f'GPU 캐시에서 메모리 삭제 후 메모리: {after_mem / (1024 ** 3):.2f} GB')
    else:
        print('CUDA 사용 불가')

# %% [markdown]
# ### 1. Summary 모델 정의

# %%
class KoBARTSummary:
    def __init__(self,
                 text,
                 model_checkpoint = 'gogamza/kobart-summarization', 
                 tokenizer_checkpoint = 'gogamza/kobart-summarization', 
                 max_length=512, 
                 device='cpu'):
        self.text = text
        self.model = BartForConditionalGeneration.from_pretrained(model_checkpoint).to(device)
        self.tokenizer = PreTrainedTokenizerFast.from_pretrained(tokenizer_checkpoint)
        self.max_length = max_length
        self.device = device
    
    def getSummary(self):
        raw_input_ids = self.tokenizer.encode(self.text)
        input_ids = [self.tokenizer.bos_token_id] + raw_input_ids + [self.tokenizer.eos_token_id]
        
        # 입력 길이 제한 초과는 제거
        if len(input_ids) > self.max_length:
            input_ids = input_ids[:self.max_length - 1] + [self.tokenizer.eos_token_id]
        
        summary_ids = self.model.generate(torch.tensor([input_ids]), max_length=self.max_length)
        result = self.tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)

        return result

# %% [markdown]
# ### 2. 데이터 불러오기

# %%
# 데이터 불러오기
with open('/Users/leesanghyuk/Python_Programs/Projects/Data/Youtube_Image/youtubeData(8331)_with_label.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
# 20개 샘플링
sampled_data = data.sample(20, random_state=seed)

# %%
sampled_data['label'].value_counts()
# Out:
# label
# 0    12
# 1     8
# Name: count, dtype: int64

# %% [markdown]
# ### 3. 요약문 생성하기

# %%
# 요약문 저장 열 생성
sampled_data['summary'] = ''


# 각 데이터에 대해 요약문 생성
for i in tqdm(sampled_data.index, desc='Creating Summary'):
    text = sampled_data.loc[i, 'content']
    model = KoBARTSummary(text)
    summary_text = model.getSummary()
    sampled_data.loc[i, 'summary'] = summary_text
# Out:
# Creating Summary:   0%|          | 0/20 [00:00<?, ?it/s]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:   5%|▌         | 1/20 [00:03<01:07,  3.55s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  10%|█         | 2/20 [00:06<00:54,  3.01s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  15%|█▌        | 3/20 [00:09<00:53,  3.12s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  20%|██        | 4/20 [00:12<00:47,  2.99s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  25%|██▌       | 5/20 [00:14<00:40,  2.70s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  30%|███       | 6/20 [00:17<00:39,  2.83s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  35%|███▌      | 7/20 [00:20<00:36,  2.79s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  40%|████      | 8/20 [00:22<00:31,  2.64s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  45%|████▌     | 9/20 [00:25<00:29,  2.67s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  50%|█████     | 10/20 [00:27<00:25,  2.59s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  55%|█████▌    | 11/20 [00:29<00:22,  2.46s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  60%|██████    | 12/20 [00:32<00:19,  2.40s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  65%|██████▌   | 13/20 [00:34<00:17,  2.48s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  70%|███████   | 14/20 [00:37<00:14,  2.43s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  75%|███████▌  | 15/20 [00:39<00:11,  2.36s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  80%|████████  | 16/20 [00:46<00:15,  3.85s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  85%|████████▌ | 17/20 [00:49<00:10,  3.45s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  90%|█████████ | 18/20 [00:51<00:06,  3.19s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary:  95%|█████████▌| 19/20 [00:53<00:02,  2.89s/it]You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# Creating Summary: 100%|██████████| 20/20 [00:56<00:00,  2.82s/it]

# %% [markdown]
# ### 4. 결과 확인

# %%
# 완료 파일 확인
def check_samples(data):
    
    # 하나씩 변경 확인을 위해 출력
    for idx, row in data.iterrows():
        print('-'*50)
        print(f"Sample {idx}")
        print('\n🔶 영상 요약 전')
        print(data.loc[idx, 'content'])
        print('\n🔷 영상 요약 전 후')
        print(data.loc[idx, 'summary'])
        print('')

# %%
# 확인
check_samples(sampled_data)
# Out:
# --------------------------------------------------
# Sample 7366
#
# 🔶 영상 요약 전
# 안녕하세요 ooo 참이 입니다 아 아 자 이번 알리익스프레스 아우른 집 꽃 템 스페셜로 꾸며봤습니다 2 이번 영상을  백과 함께 만든 영상 이거든요 도움을 쓰고 돈을 또 받는법 궁금하시다면 묶어서 보십시오 첫번째 아이템 자 꽃병을 살려고 인터넷에 검색을 해보면 은 이런 디자이너 꿈 따위 되게 많이 나오거든요 근데 이제 가격 비교를 해 보면 당연히 아이에서 사는게 훨씬 싸게 쬲 뭐 품질 갖춘 경우에는 색유리 만들때 조색 할 때 쓰는 가루가 덜 옥은 그런적 땀 요정도 품질 괜찮다고 생각합니다 요 정도 사이즈의 요정도 퀄리티 야자를 많이 키우다 보니까 아 빨리 자라라 목 가지치기를 해 줄 때 나오는 잎사귀들을 요렇게 뭐 정돈되고 요런 레고 꽃 같은것도 투자 봅니다 예쁘죠 얘가 아무래도 닿는 면적에 비해서 높이가 있으니까 길고 묵직한 거는 무엇 버티 더라구요 물 없이 꽂아 나서 그런걸수도 있고 물을 조금 담고 하면 여기가 또 묵직해 지니까 저는 울 꽂이 하거나 이럴 때 쓰려고 샀습니다 잘 삽니다 마음의 추첨 이거는 제가 전에 낙성대 맛집 아따 라거 따라 소개할 때 100 빠가 쏟자 나요 예 아 갔을 때 선생님이 이렇게 귀여운 레코드판 포스터를 주시는 거에요 않는데 소장님이 주시는거 약간 c 콘 느낌 예언도 얘는 경우 쌩으로 플라스틱 외 이것도 뭐 사실 가격대비로 생각 하면 예쁘지 않게 찌 근데 얘가 괜찮을 까 이 스티커와 깡 컴 제일 멋있는 걸로 하나 해서 먹던 음료를 맞추어 같습니다 으 루거 나쁘지 않아요 귀여워요 다음 이 옴과 아 이게 뭐냐면 따란 5 얘는 물을 여기다가 담아가지고 화분을 받고 자서 누를 주는 그런겁니다 까 내가 많이 래 요 걸 해보자 놓고 이틀 정도 자리를 비워도 이렇게 천천히 물이 급수가 되는 유리 참 찬이 급수기 어 마음이 되어 있네요 굉장히 날카로워 가지고 조금 축축한 느낌이 있다고 생각했는데 다행히 마감이 되어 있고요 사진하고 비슷하네요 근데 이런건 다 이렇게 불어 받이고 만드는거 라 모양이 일정 알 수 있는거고 워서 사용하면 예쁠거 같아요 자 다음 물건 우아한 102 할 때 뿌리는 설탕 장식 딱 층계 들어간 디자인이에요 되게 예쁘다 272 쿰 죽어 것들이 디자인이 쪼금 막 너무 주황색 아님 막 너무 형광 초록색 마 이런게 많잖아요 근데 요런 좀 예쁜 게 보이길래 가족도 개 쳐서 구매를 했습니다 아주 예쁘네요 예쁘다 마감은 딱 덜 깎을 하거나 그러지는 않아요 이 정도 괜찮은 것 같습니다 여러 용도로 잘 쓸 수 있을 것 같아요 괜찮다 다음 얽어 함 제가 이 미러볼 행잉 화분을 수공예품 인한 빈티지 같은거 파는 해외 사이트에서 봤는데 오 예쁘다 받고 싶다 배포 밟던 게 알리의 똑같이 있는거예요 당연히 훨씬 싼 가격에 4 모포 장애 상태에 이런거는 타실 알리 에서 주문할 때 좀 가만 하게 되는 부분이니까 대 초 두고 빠 란 행잉 했을 때 뭔가 멋진 모습이 보이긴 합니다 투명 플라스틱 9 같은거 에다가 거울 조각들을 다닥다닥 붙인 건데 약간 밀려 가지고 여기 이렇게 빈 칸이 생각 손을 보면은 될거 같긴 하거든요 그래서 한번 만저 보려고요 지금 보니까 얘는 물 구멍이 없어서 여기다 아이의 화분을 신는 것보다는 화분을 그래요 다 담아서 행 윙 하는 정도 로 사용을 하면 될 것 같습니다 한번 많은 우리 집에 예쁜 포인트가 되어줄 것 같아요 으 라바 램프 입니다 뭔가 영상에서 보셨을 수 있는 꼭 아 꼭 아 우어 차 깔 예쁘다 음 이제 이 밑으로 뜨끈 뜨끈한 열이 올라 오면서 이 왁스 어몽 가서 이렇게 빙글빙글 도는 그런 느낌이에요 얘를 그럼 이렇게 놓고 아 아 oo 아 예쁘다 잡혀 볼게요 조금만 어떻게 맘에 듭니다 으 아 느껴 줘 이렇게 쓸 거야 아 5 이 밑으로 밑이 들어오네 일단 지금까지는 아 좋아 맺습니다 내가 원의 또 그렇게 누가 좀 으 요 친구 여 친구는 지금 깔려있는 이 담요를 벋어 내 보면 운이 가 뭔가 스크래치 하면서 발통 박혀 들어가면서 소파에 좀 터진 부분들이 있어요 그래서 뭔가로 접고 항상 촬영을 하고 있거든요 얘도 그런 용도로 사용을 하려고 샀고 아우의 의미가 뜯기 아주 졸 소재 내 발톱이 딱 벌리게 했네 5 잇다는 요런 분이 그리고 술도 디테일 음 좀 예쁘게 들어가 있고 뭔가 전체적으로 위빙 으로 직접 땀 짬 같 같은 퀄리티 어서 마음에 드네요 활성 같아요 이건 괜찮다 초 4 수동 추첨 그리고 이건 뭐지 아 얘도 평입니다 아 자꾸 귀엽죠 싶어서 풀을 많이 키우다 보니까 번식이 되는 친구들은 생장점 만한 짜르면 짤라서 물에 꽂아서 뿌리가 또 나면 개를 이제 흙에 옮겨 심고 하는 과정들이 많거든요 그래서 꽃병을 되게 많이 써요 그런데 꽃병이 너무 크면 살 일도 많이 찾아 봐요 그래가지고 좀 작은 꽃병을 살려고 구매했고 요렇게 이렇게 꽂아 가지고 쓸 수 있는 꽃병 이고 흠잡을 것 처럼 는 조 없어 괜찮아요 귀엽다 추천합니다 이건 뭐지 주방장갑 수방 장갑 제가 갖고 있는게 탈 부분이 있어 가지구 구매했는데 봐 0 아주 미묘하게 이쪽 원담 보다 이쪽 언다 2 발매 요하 아주 미묘하게 하지만 안 해도 이렇게 제대로 누빔 처리가 되어 있고 잘 해줄것 같습니다 그 문제는 한 짝만 주네 그 한 짝만 준다고 나한테 말 핸 했어 썩 2개를 주겠다고 말한 적은 없네요 별첨 4 귀엽네요 3,400 어메 구매를 했으니까 2짝 싸면 6000원 일꾼이 야 오 아 오 빠 올라온다 보이네요 포 이브 프 여러분 이구요 이 왁스 올라오는 거고요 o 아앗 아 이거 잘 샀네 나 이거 너무 맘에 든다 아 진짜 귀엽다 이게 이렇게 빙글빙글 돌아 다닐 거 아니야 색깔도 너무 예쁘고 진짜 마음에 들어요 오븐 장갑을 마지막으로 알리 익스프레스에서 제가 구매한 짚고 용 제품들은 끝이 거든요 그런데 일단 제일 맘에 드는 건 역시 라바 램프 라바 램프 줘 너무 맘에 드리고요 불 보면서 멍 때리는 것 불 멍이 라 하듯이 램 멍이 가능할 것 같은 진짜 마음에 들어요 아 예랑이 에는 너무 귀여워서 강추 요렇게 두개 나도 너무 귀엽게 따 그래도 괜찮은 것 같아요 실리콘 알뜰주걱 업계에서 예쁨을 가져가려 좀 어려운데 예쁘다 자 물에 바쳐 하더니 코스터 스티커 부문 괜찮을 것인가 어찌 거 좀 문제가 없네요 가격대비 비오니까 괜찮은듯 얘는 충분히 인테리어 포인트가 되어줄 것 같다 얘도 괜찮다 이물 졸이게 귀여워요 전반적으로 굉장히 성공적으로 오쇼핑을 마치 인것 같고요 이번에 알리 익스프레스에서 제가 구매 아니 인테리어 소품들은 모두  빽 을 경유해서 구매했습니다 그래서 4 - 무엇이냐  백은 캐시백을 주는 리워드 플랫폼 인데요 이게 그냥 포인트가 아니라 실제 현금을 통장으로 꽂아주는 알짜배기 사이트입니다  100에서 경우에서 들어갈 수 있는 쇼핑몰들이 250개 이상 있으니까 5차 p 돈을 쓰고 쇼핑을 할 거라면 간단히  팩을 경유해서 접속하기 만 해도 최대 20% 가량의 캐시백을 받을 수 있던 더는 하시  빽을 이번 기회에 처음으로 사용을 했는데 친구가 이미  팩을 오랫동안 사용하고 있었더라구요  패킷이 102 물건을 받는 배송 기간도 있고 누가 캐시 100만 받은 다음에 그냥 환불을 해 버릴 수도 있기 때문에 기타 절차들을 다 보려 를 하면 캐시백을 실제 사용 하기 까지 2 3개월 가량이 소요 가 텐데요 그 친구 얘기를 들어보니까 어차피 나는 쇼핑을 하는거고 계속 쇼핑을 하다보면 e 3개월의 공백은 처음 쇼팽을 사용하고 나서 많이 3개월을 기다리는거 고 그 이유로는 네가 쇼핑을 한 텀 만큼만 기다리면 그 틈 틈 틈 마다 캐쉬 맥이 쏙쏙 들어온다 것 그렇게 조금씩 솔솔 모인 현금 들은 5천원 이상이 되면 이제 파기 통장이나 네이버 페일 통해서도 캐쉬백이 가능하다고 합니다 제가 한번 접속을 해 볼게요 이렇게 들어가면 메인화면에 있는 내가 쇼핑 하려던 사이트 를 누르면 바로 이동이 되거든요 그러면 여기 이제 보면 씹에 기온을 몇 퍼센트 인지도 떠있는 거 고착 빽 에서 뭔갈 결제 하는게 아니라 차 팩을 통해서 경유해서 들어간 다음에 내가 평소에 하던 것처럼 그냥 결제를 하면 48시간 내에 여기 어플 알림에 내가 적립할 수 있는 캐시비 기 뜹니다 이렇게 보시면 저도 이번에 짚고 하면서 구매한 물건 게시 100 뜰이 이렇게 남아 있고 총 합치면 전체 캐시 베크 맥이  ...
#
# 🔷 영상 요약 전 후
# 이번 알리익스프레스 아우른 집 꽃 템 스페셜로 꾸며진 영상에서 백과 함께 만든 영상 이어서 도움을 쓰고 돈을 또 받는법 궁금하시다면 묶어서 보십시오
#
# --------------------------------------------------
# Sample 4051
#
# 🔶 영상 요약 전
# 최근 김하성과 타티스 주니어의 평가가 엇갈린 가운데 코리안 메이저리거 기마성의 몸값이 친정부지로 오르고 있습니다 현재 페르난도 타티스 주니어가 징계를 마치고 샌디에이고로 돌아와도 유격수가 아닐 가능성이 커보인다는 외신들의 평의 집에 있습니다 aj 프렐라 샌디에이고 사장이 간판스타 페르난도 타티스 주니어의 멀티 포지션 가능성을 공식적으로 언급하면서 사장 역시 김하성에 대한 기대를 숨기지 않고 있다는 것입니다 지난 10월 금지 적발로 징계를 받은 파티스 주니어는 내년 4월 21일까지 메이저리그에서 뛸 수 없는 상황에서 최근 김하성이 공수 양쪽에서 성장의 유격수를 고민할 필요가 없기 때문입니다 얼마 전 열린 메이저리그 단장 회의에 타티스와 포지션 변경 문제를 놓고 심도 깊은 대화를 나누고 있다고 밝혔습니다 지난 시즌 샌디에이고는 역대 가장 큰 거액의 계약을 체결한 파티스 주니어를 메 주식을 슈퍼스타가 될 것이라 확신에 찾지만 오프 시즌서 발생한 오토바이 사고로 어깨 수술을 해 팀의 민폐를 끼치더니 복귀를 앞두고는 금지 약물 검사에서 양성반응이 나와 8경기 출장 정지를 받았기 때문입니다 미국 JN 스포츠에 따르면 파티스 주니어의 애매해진 수비 포지션도 적지 않은 영향을 끼쳤는데 특히 타티스가 20홈런 이상 칠 수 있는 어린 유격수라는 점 때문에 초대형 계약을 안겨준 것일뿐 수비면에서는 샌디에이고 평균 기댓값보다 못하는 평을 내렸고 그런데 기다렸다는 듯이 타티스 주니어가 없는 동안 그의 공백을 기마성이 채우며 골든 글러브 후보까지 등극하는 등 구단 내에서조차 예상밖에 활약에 타티스 주니어의 입지가 좁아지고 있던 것입니다 하지만 어디까지나 언론의 예상일뿐 샌디에고는 타티스 주니어의 내년 외야 이동의 명확한 답변을 내놓은 적은 없었지만 결국 프렐러 단장이 개인적으로 타티스 주니어에게 포지션에 대해 공식적인 언급이 발표되자 흐름이 180도 바뀌었습니다 프렐러 사장은 파티스는이기는 것이 가장 큰 목표라고 한다 내년 스프링캠프에서 우리가 그에게 기대하는 점이 무엇인지 확실히 하면서 어떤 옵션이 있는지 알려주고 적응 여부를 살펴볼 계획이다라며 다양한 포지션에서 뛸 가능성도 논의할 것이라고 언급한 것입니다 지금까지 타티스 주니어는 메이저리그에서 2루수로 뛴 적이 없고 마이너리그에서도 2017년 한 경기를 끝으로 이로 수비에 나선 적이 없는데 어느 하나 풀타임 주전 자리를 맡기기엔 애매한 선수라고 말할 수도 있습니다 파티스의 포지션 변경 가능성이 꾸준히 제기된다는 것은 곧 샌디에이고가 주전 유격수 기마성을 원한다는 얘기가 되는 것입니다 미국 dlatic 데니스 링 기자에 따르면 27살 김하성은 올해 골든 글러브에 도전했고 공격에서 눈에 띄는 발전 잃었다고 호평했습니다 그래서 사장은 타티스 주니어가 자리를 비운 사이 기마성이 등장하면서 모든 것이 바뀌었고 빈자리를 매운 기마성은 올해 582타석에 나서 11홈런 조정 OPS 107을 기록했으며 그런 기마성을 유격수에서 옮길 이유가 샌디에이고에게는 없을 것입니다 그러나 일각에선 구단이 기마성을 긍정적으로 바라본다 한데 타티스 주니어의 고집 때문에 유격수 경쟁은 더욱 치열할 것으로 보인다 밝혔습니다 그도 그럴 것이 타티스가 샌디에이고와의 계약 당시 주전 유격수를 보장해 줄 것을 계약 내용의 기재되어 있을 것이고 특히 테티스는 여전히 육격격수 자리를 원하고 있기 때문입니다 하지만 파티스의 생각과 달리 샌디에이고 파드리스 팬들은 기마성을 유격수로 보내는게 맞다는 입장입니다 인터뷰 내용에 따르면 그동안 파티스가 금지한 물로 메이저리그 기록을 세웠다면 약물 적발이 있던 선수가 성 부정적인 복귀는 그 누구도 없었다며 의구심을 내비쳤던 것입니다 espn도 기마성을 썩히는 것은 미친 짓이라며 차라리 타티스를 외할수 이처럼 다수 매체 유격수의 자리는 김하성의 것이라는 발언은 단순한 립 서비스로 보기는 어렵습니다 1년 전만 하더라도 김하성의 빅리그 주전자리는 상상하기 힘들었고 기존 선수의 부재로 생긴 기회를 확실하게 잡으며 당당하게 주전으로 올라섰습니다 이제는 미국 현지의 믿음도 점점 굳건해지는 분위기인데요 올해 샌디에이고는 정규시즌 89승 73패로 내셔널리그 와일드카드 2위로 포스트 시즌에 진출하는데 성공했으며 뉴욕 매치와 LA 다저스를 차례로 만나는 힘 대진이었지만 각각 2승 1패 3승 1패로 손쉽게 제압하고 챔피언십 시리즈까지 진출했습니다 파티스 주니어가 외야수로 포지션을 옮겨도 부상 위험해서 완전 자유로울 수 없다는 점을 지적했습니다 야구 포지션에서 어깨 부상 발생 비율이 육격수 2루수의 중앙내아가 12.9%이고 외야에선 31.6%라는 연구 결과를 근거로든 것인데요 반면 1루수의 어깨 부상 비율은 7.4%에 불과한만큼 카티스 주니어에게 가장 적합한 포지션이라는게 지배적입니다 그런데 메이저리그 최고 명문구단 뉴욕 양키스의 감독이 김하성 영입을 위해 비밀리에 추진하고 있다는 소식이 들려오고 있습니다 북미 뉴욕전 스포츠에 따르면 뉴욕 양키스의 앨런분 감독을 비롯해 양키스 구단 관계자들은 이번 포스트시즌 무기력한 패배의 원인은 양키스 내야진 수비가 문제라고 밝혔습니다 최근 양키스 수비수가 매우 불안하다라며 김하성이 양키스 유격수 자리를 꿰찰 것이라고 전했는데요 일각에선 샌디에이고에서 잘 적응하고 있는 기마성이 이적하는 건 말도 안 된다며 소리쳤지만이는 양키스 내부 관계자들의 발언으로 사실화되고 있습니다 에런본 감독은 휴스턴과의 4차전 경기 후 패배 원인에 대해 결정적인 수비 실책으로 인해 모든 것이 뒤바뀌었다며 양키스의 내야지는 내년 필요하다고 밝혔던 것입니다 뉴욕 안키스가 다가오는 이적 시장에서 대대적인 선수 방출을 단행할 것으로 예상되며 특히 김하성의 영입은 이미 내부 관계자들로부터 확인된 사실입니다 양키스 스카우터 존 맥켈에 따르면 현재 가장 포텐셜이 좋고 젊은 수비수를 대거 영입할 예정이다라며 여전히 젊고 대단한 활약을 했던 김화성을 지칭하는게 아니냐는 여론이 흘러나오고 있습니다 이에 양키스 팬들은 샌디에이고가 타티스 주니어를 육격수로 보낸다면 차라리 양키스로 이적을 해줬으면 좋겠다는 입장을 밝히나 있습니다 이번 트레이드에 관해 기마성 에이전시는 언론과의 접촉을 최대한 피하는 상황인데요 기존 선수의 부재로 생긴 기회를 확실하게 잡으며 당당하게 주전으로 올라선 기마성의 내년 활약이 벌써부터 기대가 되는 모습입니다
#
# 🔷 영상 요약 전 후
# 샌디에이고의 간판스타 페르난도 타티스 주니어의 멀티 포지션 가능성을 언급하면서 김하성에 대한 기대를 숨기지 않고 있는 가운데 샌디에이고 사장이 김하성에 대한 기대를 숨기지 않고 있다는 것입니다
#
# --------------------------------------------------
# Sample 3049
#
# 🔶 영상 요약 전
# 어느 한 지층에서 발자국으로 만 확인된 공룡들이 있고 뼈로 안 나오는 애들이 있어요 발자국 화석이 남겨질 수 있는 좋은 환경은 뼈 화석이 보존될 수 있는 환경이랑 되게 달라요 뼈 화석은 얘가 죽은 다음에 바로 묻혀야 돼요 특히 이제 강가 근처에서 많이 뼈 화석이 보전이 되거든요 왜냐면 강 주변에는 물살 다 세고요 깎아낸 모래라는 이런 것들 덤핑을 해요 그럼 뼈들이 보전이 되겠죠 발적 화석은 퇴적이 빨리 되면 안 되겠죠 거기 갑자기 물이랑 모래가 온다 하면은 다 훼손이 되겠죠 현장 자체가 보존이 돼야 돼요 호수가 잔잔한데 있잖아요 근데 우리나라는 다 바닷 가잖아 지금은 바닷가인데 옛날에는 호수가 일본이 이렇게 붙어 있었고요 북쪽이 남쪽으로 산맥으로 둘러 쌓여 아 그래서 일본하고 그 사이가 다 호수였다 공룡이 진흙을 밟고 갔어요 모래라는 아니면 좀 더 입자가 큰 다른 계열의 진흙이 덮여 져야 돼요 호수물이 가까워서 안 되고 너무 멀어서 안 돼요 정말 보존 되기가 힘들어요 근데 우리나라는 되게 많이 나오죠네 근데 아마 진주가 제일 많을 거예요 수천개 될 거예요 거기는
#
# 🔷 영상 요약 전 후
# 어느 한 지층에서 발자국으로 만 확인된 공룡들이 있고 뼈로 안 나오는 애들이 있어요  뼈 화석이 보존될 수 있는 좋은 환경은 얘가 죽은 다음에 바로 묻혀야 돼요 특히 이제 강가 근처에서 많이 뼈 화석이 보전이 되거든요 왜냐면 강 주변에는 물살 다 세고요 깎아낸 모래라는 이런 것들 덤핑을 해요 그럼 뼈들이 보전이 되겠죠  호수가 잔잔한데 있잖아요 근데 우리나라는 다 바닷가인데 옛날에는 호수가 일본이 이렇게 붙어 있었고요 북쪽이 남쪽으로 산맥으로 둘러 쌓여 아 그래서 일본하고 그 사이가 다 호수였다
#
# --------------------------------------------------
# Sample 4914
#
# 🔶 영상 요약 전
# 최근 김하성 선수와 관련된 MLB 매체들의 분석 보도가 이어지며 미국 야구팬들 사이에서 큰 화제를 모으고 있습니다 MLB 매체들은 김하성 선수의 최근 경기 성적들을 조명하며 그의 가치를 좀 더 면밀하게 분석했는데요 이에 해외 야구팬들의 반응이 뜨겁습니다 또한 이와 함께 최근 멜빈 감독이 김하성 선수에 대해 꺼낸 발언도 함께 전해지며 연일 해외 야구 전문 커뮤니티들을 떠들썩하게 만들고 있는데요 김하성 선수를 향한 MLB 매체들의 분석과 해외 야구팬들의 반응 자세히 알아보도록 하겠습니다  한국시간 6일 MLB 전문매체 mlb닷컴에서 흥미로운 기사를 전했습니다 mlb닷컴은 김하성 선수의 멈출 줄 모르는 폭풍활약상들을 소개하며 김하성의 가치가 어디까지 치솟을까 이번엔 메이저리그 최고 2루수 후보 중 하나로 언급됐다는 속보를 전했는데요 매체는 올해 갑 포지션에서 최고의 선수는 누구였나 남은 시즌 동안 각 포지션에서 최고의 선수들을 분류해 유력하고 경쟁자 다크호스로 분류할 것이다 오늘은 2루수 후보라고 밝혔습니다 이와 함께 김하성 선수를 올 MLB 2루수 후보 경쟁자로 전체 8명 중네 번째로 언급했는데요 2019년 이후로 매년 선정되고 있는 올 MLB이 랭크는 팬투표 50%와 전문가 패널 투표 50%로 선정되는 기준을 가지고 있고이 팀의 후보는 오는 11월에 발표되고 최종 발표는 12월에 이뤄질 예정입니다이 지표는 각 리그를 가리지 않고 한시즌 동안 포지션 별 최고의 활약을 펼친 선수를 1팀과 2팀으로 나눠 선정하는 방식을 가지고 있는데요 각 팀은 포수와 일루수 2루수 유격수 3루수 특정 포지션 상관없이 외야수 3명과 지명타자 한 명 선발 투수 5명과 2명의 구원투수로 구성되고 있습니다 때문에이 지표 후보의 선정됐다는 것 자체가 MLB 내에서 얼마만큼의 활약상을 펼치고 있는지 mlb의 대부분이 인정하는 것과도 다름없는 그런 영향력 있는 지표인데요 최근 적극적인 주루 플레이로 31도로를 기록한데 이어 언제나 역대급 수비 장면들을 연출해내고 있는 김하성 선수 역시 mlb네에서 손꼽히는 화제의 인물로 선정되었습니다 매체는 김하성은 유력 후보인 마르코스 세미엔 루이스 아라이즈에 이어 경쟁자 부문으로 분류돼 아직 알비스에 이어 전체에서네 번째를 차지하게 됐다 김하성은 앞 war4.4를 기록했고 팀 내 최고 타율인 er7 놀이 출루율 0.365 장타율 0.429 OPS 0.794 17홈런으로 샌디에이고에서 가장 있는 선수로서 자리매김하고 있다고 소개했습니다이어서 이루수올 MLB 후보들의 공통 주제이기도 한 것처럼 김하성은 특별히 강한 타구를 치는 것은 아니지만 정확한 스팟의 마침으로써 일을 만회한다 추격률 93이 허스익률 91위에 랭크돼 있다 나아가 이미 31개의 도로를 작성했고 계속해서 경고한 수비를 펼치고 있다 수비득점 세이브는 10으로 2루수 4위를 기록하고 있다고 평가했습니다 매체는 김하성 선수가 MLB 전역에서 이렇게 지대한 관심을 받게 된 이유를 조명했는데요 매체는 김하성의 뛰어난 수비 능력은 지난해부터 각광을 받기 시작했다 내셔널리그 골드글러브 최종 후보 3인의 이름을 올릴 정도로 뛰어난 수비력을 인정받았다 올 시즌 주로 2루수로 나서고 있지만 3루수와 유격수를 오가며 호수비쇼를 펼치고 있다 그러나 더 놀라운 건 눈에 띄게 성장한 타격 능력이다 빅리그 3년차인 김하성은 첫 시즌 타율 이할 1위로 크게 어려움을 겪었다 빠른 공은 물론이고 변하고 대처 능력에서도 높은 벽을 체 것이다 지난 시즌 타율 2열 오픈릴리의 두 자릿수 홈런으로 진일보안끄는 올시즌 한 단계 더 성장한 면모를 보였다 홈런은 17개나 날리며 20홈런까지 3개만을 남겨뒀다 빠른 발도 강점이다 헬멧이 벗겨질 정도의 적극적인 주류는 이미 김하성의 트레이드 마크가 됐다 싸일 미국 캘리포니아주 샌디에이고의 백호 파크에서 열린 샌프란시스코 자이언츠와 2023 MLB 홈경기에 한번 타자 겸 2루수로 출전해 도로 두 개를 더한 김하성은 홈런 3개를 추가할 경우 아시아 내야수 최초로 20홈런 30도로를 기록하게 된다 아시아 내야수로는 22일 작성한 선수조차 없었다라고 칭찬을 아끼지 않았습니다 MLB 전문매체가 이렇게 극찬할 정도로 김하성 선수를 향한 관심과 인기도가 미국 전역에서 상당한데요 또 다른 매체 MLB 트레이드 루머스 역시 김하성 선수의 놀라운 발전에 대해 칭찬을 보내며 도대체 어떻게 그가이 자리까지 올라오며 급성장을 이룩해낼 수 있었는지를 분석했습니다 올 시즌 샌디에이고는 많은 돈을 투자하고도 기대를 믿 있다 그러나 올해 크게 발전하며 리그 최고의 내야수 중 하나로 거듭나고 있는 김하성이 있다 그 많은 부진한 샌디에이고에서 홀로 고고하게 빛나고 있다고 소개했습니다 매체는 수비력보다 더 인상적인 건 공격력에서 도약이다 지난해 평균 이상의 공격력으로 성장했다면 올해는 올스타급 타격 능력을 갖춘 선수로 성장했다 그의 수비 능력과 함께 크게 향상된 공격력을 바탕으로 샌디에이고의 팀 mvp를 넘어 NL mvp급 선수로 성장했다고 극찬했습니다 마지막으로 김하성이 mlb를 특히나 열광시키는 데에는 바로 그의 성장 배경에 있다 꾸준한 노력을 통해 실력이 일취월장해지며 급성장한 경우가 MLB 자체에 대해서 별로 없을 뿐더러 이런 성장 스토리를 싫어할 사람은 아무도 없기 때문이다 김하성이 어디까지 성장할지 mlb의 모두가 그를 지켜보고 있다고 덧붙였습니다 김하성 선수의 활약상들과 그의 대단함이 조명받음에 따라 당연히 그의 가치가 어느 정도 상승했는지도 화제거리가 되고 있는데요 MLB 전 멜빈 감독의 김하성 선수 관련 발언들의 전하면서 그의 가치가 어느 정도 될지를 추측했습니다 매체는 김하성의 4+1년 3,900만 달러 계약은 2024시즌을 끝으로 종료될 가능성이 크다 기마성이 올 시즌을 기점으로 메이저리그 탑클래스 공수주 겸장 2루수가 되면서 2025시즌 800만 달러 옵션을 굳이 실행할 이유가 없기 때문이다 사실상 2024시즌이 예비 FA 시즌이 될 것으로 보인다 1995년생 김하성은 2025년이 돼야 30대다 내년에 크게 부진하지만 않다면 2024 2025 FA 시장에서 몸값이 폭등할게 확실하다 이건 자연스럽게 따라오는 것이다 오히려 더 중요한 건 가치이고 명예다 어쩌면 몸값보다 더 중요한 영역이다 프로로서 제대로 인정받는 것만큼 의미 있는게 있을까 김하성은 그만의 시그니처 강한 타구가 있는 건 아니지만 그는 체이스 레이트 상이 93%, 퍼스익률 상위 91%로 만회한다 그의 스트라이크 존의 오는 공은 기가 막 잘 친다는 것이다 이런 공격까지 해낼 수 있는 내야수를 원하지 않을 팀은 mlb의 전무할 것이다 그의 연봉 700만 달러는 그의 활약상에 비해 너무 헐값이다이는 야구팬들을 실망시키는 일이다 그가 재계약을 하게 되면 지금 연봉의 최소 2배 3배는 받게 될 것이라고 전했습니다 그러면서 매체는 샌디에이고 구단 내에서도 김하성을 향한 신뢰가 대단하다 라면서 멜빈 감독의 발언 역시 함께 첨부했는데요 멜빈 감독은 구단과 1500승 기념 인터뷰에서 현재 팀 선수들에 대한 질문을 받고 칭찬을 이어나갔습니다 당연히 김하성 선수도 그 리스트에 있었는데요 평소 언론 인터뷰에서도 지속적으로 김하성 선수를 호평했던 멜빈 감독은 모든 것을 다 해낸 시즌이라고 총평하며 강한 신뢰를 드러냈습니다 멜빈 감독은 그는 전진 배치된 뒤 리드오프 자리를 굳건히 했다 다양한 포지션을 소화하고 있고 평균 이상 플레이와 평균 이상의 수비를 해내고 있다 오늘 왼손 투수가 마운드에 있다면 그를 3번 투입할 수 있고 오른손 투수가 있다면 우리는 그를 두 번의 투입할 수 있다면서 수비는 물론 공격도 다양한 활용이 가능한 엄청난 재능을 가지고 있다고 강조했습니다 이어 도로 중요한 안타 리드호프 홈런 일반적인 홈런까지라고 김하성 선수가 최근 해왔던 일을 나열한 뒤 환상적인 한 해였다 그리고 그에게는 아직 한 달이 남았다 그를 위해 더 성취해야 할 것들이 있다 그리고 지금이 시점에서 31개의 도로는 매우 멋진 숫자라고 김하성 선수의 올라운드 활약에 찬사를 보냈습니다 이처럼 김하성 선수의 가치가 MLB 전역에서 인정을 받고 있는 가운데 앞으로도 김하성 선수를 응원하며 지금까지 월드 러닝타임이었습니다 구독과 좋아요는 큰 힘이 됩니다 감사합 ...
#
# 🔷 영상 요약 전 후
# MLB 매체들의 분석 보도가 이어지며 미국 야구팬들 사이에서 큰 화제를 모으고 있는 김하성 선수의 가치가 어디까지 치솟을까 이번엔 메이저리그 최고 2루수 후보 중 하나로 언급됐다는 속보가 전해지며 해외 야구팬들의 반응이 뜨겁다.
#
# --------------------------------------------------
# Sample 5353
#
# 🔶 영상 요약 전
# 현재 박항서 감독을 떠나보낸 베트남이 인도네시아에 충격패를 당하며 동남아시안 게임에서 떨어진 가운데 박항서 후임 감독의 폭탄 발언이 베트남 현지를 경악하게 만들고 있습니다 박항서 후임 감독인 트로시의 감독은 베트남 축구대표팀의 부임하면서부터 스트레스에 연속이었습니다 베트남 축협은 다가오는 2026년 동남아 최초로 월드컵 본선에 반드시 진출해야 한다며 허구한 날 압박했고 베트남 언론들은 심심하면 박항서 감독과 비교를 하며 박항서 감독이 그립지 않게 박항서 감독보다 더 많은 우승 트로피를 선물해달라고 전했습니다 베트남은 이번에 열린 동남아시안 게임에서도 과거 박항서 감독이이 대회에서 2연패한 것을 상기시키며 베트남이 당연히 우승해야 하는 대회라며 떠들었는데요 베트남이 인도네시아의 충격패를 당하며 대회에서 탈락하자 베트남 전체가 뒤집혔습니다 당장 트로시의 감독을 경질시키고 박항서 감독만큼 할 수 있는 감독을 영입해야 한다고 소리쳤습니다 그런데 이런 상황에서 트루시에는 말 그대로 팩트 폭격을 날려서 엄청난 화제가 됐습니다 베트남 언론이 당연히 트루시의 감독은 박항서 감독이 했던 것만큼은 해야 한다고 말하고 그동안 쭉 박항서 감독과 비교해 온 것에 화가 나 있던 트루시에는 결국 폭발했는데요 그는 베트남의 현실을 촌철살인의 한마디로 정확히 알려주며 기자회견장을 경악하게 만들었습니다 과연 어떤 말을 했는지 자세한 내용 알아보겠습니다 동남아 최강이던 베트남이 동남아 올림픽이라 불리는 동남아시안 게임서 탈락했습니다 그러자 베트남 언론들과 팬들은 즉각적으로 박항서 감독을 찾았습니다 대회 3연패를 노리던 디펜딩 챔피언 베트남은 동메달 결정전으로 떨어졌습니다 베트남은 지난 두 대회 연속 우승을 차지한 바 있습니다 2019년과 코로나19 때문에 1년 연기되면서 지난해 열린 2021 대회에서 있다가 우승을 차지했습니다 베트남은 두 번 모두 태국과 결승에서 만나 1대0으로 승리 우승컵을 알았습니다 모두 박항서 감독 시절 쌓은 금자탑이었습니다 하지만 이번 대회에서 베트남은 인도네시아를 상대로 수적으로 우세한 경기를 펼치고도 번번이 결정적인 기회를 놓쳤습니다 결국 경 종료 직전 결정적인 중거리 슈팅을 허용하며 무너졌습니다 그러자 케네14 등 많은 베트남 언론들이 박항서 전 감독을 찾았습니다 박항서 감독을 트루시의 감독과 비교한 것입니다 트로시의 감독에게서는 박항서 감독의 리더쉽이 보이지를 않는다 박항서 감독이 경기장에 있으면 어떤 상대든 이길 수 있을 것 같은 인상을 줬다 하지만 트로시의 감독은 전혀 다르다 박항서 감독 시절에 단단한 조직력도 없다 박항서 감독은 무엇보다 팀의 결속을 중요시했고 특히 수비 조직력을 탄탄하게 만들었다 선수들은이기는 법을 알고 있었다 트로시의 감독이 팀을 맡은 지금은 선수들이 너무나도 헐거워진 느낌이다 이날 박항서 감독이 경기장을 찾아왔었다 경기가 끝나고 수많은 베트남 팬들은 박항서 감독을 향해 울부짖었다 경기 내용보다 박항서 감독의 방문이 더 화제가 됐다라고 언론들은 보도했습니다 박항서 감독은 이틀 전 일대일로 비긴 태국과 가진 조별리그 마지막 경기를 보기 위해 경기장을 찾기도 했습니다 당시 많은 현지 언론들이 박정 감독의 방문에 높은 관심을 보였습니다 박항 감독은 이날도 경기장을 찾았습니다 하지만 경기 집중력을 흐트릴 수 있는만큼 마스크를 쓴 채 조용히 경기를 지켜봤습니다 베트남 매체는 베트남 대표팀이 2대3으로 패하며 결승 진출이 좌절되자 트루시의 감독에 대한 비난이 커졌다 동남아시안 게임 2연패를 이끌던 베트남은 어디에 있는 것인가라고 보도했습니다 또한 경기에서 패배우 기자회견장의 참석한 트루시의 감독을 향해 박항서 감독이 이끌던 시절의 베트남 축구가 보이지 않는다 이게 어떻게 된 일인가 박항서 감독의 업적을 넘기 위해 당신을 선임했다 하지만 결과가 따르지 않은 것에 대해 어떤 책임감을 갖고 있는가라고 물었습니다 질문을 듣던 트로시의 감독은 잠시 눈을 질끈 감았는데요 그리고 이후 베트남 전체가 경악할 정도의 팩트폭격을 선사했습니다 올해 박항서 감독님은 베트남 대표팀 감독으로 5년여의 여정을 마무리했습니다 그리고 저는 베트남 유소년 대표팀을 맡으면서 오랜 시간 박 감독님과 함께 해왔습니다 그런데 당신들은 박 감독님의 업적을 잘 이해하지 못하고 있습니다 그의 업적은 수많은 우승 트로피 말한 것이 아니에요 베트남 축구의 역사 자체를 바꾼 것입니다 그것이 어떤 의미인지 생각해봐야 합니다 박 감독님의 업적을 당연하게 여기는 당신들의 태도가 얼마나 웃긴지도요 박 감독님은 베트남의 축구를 180도로 바꿔놓았습니다 박 감독님 체제에서 성장한 베트남 선수들이 해외 구단의 부름을 받는 일까지 생겼죠 공격수인 응우엔 꽁포엉이 벨기에 신트트라위던에 입단한 것은 베트남 선수 최초의 유럽 진출 사례였습니다 박 감독님이 부임하기 이전에는 꿈도 꿀 수 없는 일이었죠 동남아 지역에서 한국 지도자들의 인기가 높아진 데에도 박 감독의 역할이 적지 않습니다 그러니까 내가 하고 싶은 말은 박 감독님은 베트남을 넘어 동남아 축구 역사의 한 획을 그은 감독이라는 겁니다 과연 그가 없었다면 베트남이 그렇게 많은 우승을 할 수 있었을까요 저뿐만이 아니라 그 누구에게도 박 감동만큼의 업적을 당연히 내야 한다고 말한다면 그 말은 부당한 말일 겁니다 그가 동남아 역사상 최고의 감독이라는 것을 알고 있다면 말이죠 트루시의 감독의 말은 베트남인들의 뼈를 때렸는데요 일본 베트남 팬들은 어떤 반응을 보였을지 알아보겠습니다 베트남의 라이벌 의식을 갖고 있고 태국 축구의 거장인 남산 단장조차 박항서 감독에게는 존경의 뜻을 나타냈다 그는 베트남 언론에 직접 나와서 박항서는 동남아시아 축구를 바꿨다고 말했지 트로시의 감독의 말이 맞다 이것만 봐도 박항서 감독을 잡지 않은 베트남이 얼마나 멍청한 짓을 했는지 알 수 있다 베트남 축구는 박항서 감독의 정과 후로 나뉜다 5년 전만 해도 베트남은 말레이시아 인도네시아와 경쟁하던 동남아 2인자 그룹이었다 그러나 박항서 감독은 모든 것을 바꿔놨다 동남아 무대에선 태국의 여전히 강해도 더 넓은 아시아 무대에서는 베트남의 실적이 크게 앞선다 경쟁자였던 말레이시아와 인도네시아는 베트남 앞에서 명함도 내밀지 못했다 이게 다 박항서 감독 한 명이 바꿔놓은 것이다 박항서 감독은 단순한 전술가가 아니었다 선수 갈아넣기나 일회성 전략에 의한 한두번의 반짝 정도로 끝난 것이 아니라 기본 포텐셜과 축구 실력 자체의 성장을 이루었고 그로 인한 장기적인 베트남 성장을 바라볼 수 있게 되었다 우리는 왜 진작 이런 것들을 깨닫지 못했을까 트루시의 감독의 말대로 박항서 감독은 그저 트로피만 수집한게 아니라 동남아 역대 최고의 감독이다 v만지 1년 만에 베트남에 피파 랭킹이 배기로 올라갔다는 소식을 뉴스로 접할 때 기억이 아직도 생생하다 그가 베트남의 부임할 때 한 약속이 100일을 이루겠다는 것이었는데 부임 1년 만에 일어내버린 것이다 또한 1년 만에 베트남의 스즈키컵 우승까지 이뤄냈지 박항서 감독은 신이 내린 선물이었다 박항서 감독이 너무 그리워서 견딜 수가 없다 그는 진정으로 선수들을 사랑할 줄도 아는 감독이었다 2018 아시안 게임이 한창 진행 중이었을 때 박항서 감독은 직접 발 마사지 기계를 들고 선수들의 발을 정성스레 문질렀다 그는 선수들에게 아버지 같은 존재였을 것이다 박항서 감독이 다시 한번 베트남 감독으로 와줄 가능성은 없는 걸까 박항서 감독은 당초 베트남 감독을 오래할 생각도 없었다 그는 퇴임할 때 낯선 베트남의 장기간 있을 것으로 생각하지 못했다 생각보다 긴 말했었다 세상에는 예외적인 일이 많이 일어나듯이 박항서 감독이 다시 한번 베트남 감독을 맡아 월드컵 본선에 도전해 주었으면 한다 박항서 감독은 스스로 열심히 하는 사람이지 뛰어난 사람은 아니라고 했다 하지만 그것은 잘못된 말이다 박항서 감독은 두 번 다시 베트남에서 볼 수 없는 역대급 감독임에 분명하다 겸양의 말과 달리 그는 베트남에서 놀라운 성과를 냈다 박항서 감독이 지휘봉을 죽이 전 베트남 대표팀 성적은 참담했다 베트남의 피파 랭킹은 142권 동남아시아의 축구 맹주 자리도 내준지 올해였다 그와의 이별을 되돌릴 수 없다고 생각하니 눈물이 흐른다 트로시의 감독의 말대로 우리는 박항서 감독의 업적을 ...
#
# 🔷 영상 요약 전 후
# 베트남 축구 베트남 축구대표팀의 사령탑 트로시의 감독이 베트남 축구대표팀의 부임하면서부터 스트레스에 시달렸으며 베트남 언론들과 팬들은 박항서 후임 감독에게 팩트 폭격을 날려 엄청난 화제가 되었다.
#
# --------------------------------------------------
# Sample 4012
#
# 🔶 영상 요약 전
# 시청 해 주셔서 진심으로 감사합니다 러시아가 실효 지배하고 있는 쿠릴열도 에서 러시아가 사실상 일본을 적국으로 가정하고 1월 8일에 지대공 미사일을 발사하지 자 일본이 당혹감을 감추지 못하고 있습니다 특히 일본의 앞마당 이라고 할 수 있는 이틀후 푸 섬에서 발사한 것으로 보여 일본이 더욱 긴장하고 있는 것으로 보입니다 일본엔 지금도 러시아를 향해 쿠릴 열도 내기 섬을 돌려달라고 요구하고 있습니다 그런데 이번에 러시아가 지대공 미사일을 발사하는 등 강경하게 대응하자 일본의 계획은 완전히 수포로 돌아가게 되었습니다 지난 1월 8일 러시아의 쿠릴열도 에서 지대공미사일 s300 v4 발사 훈련을 실시했다고 러시아 정부가 밝혔습니다 러시아의 극동 지역을 관할하는 부대 낸 동부 0 강구 인데요 동부 공관 분 n 이번 미사일 발사 훈련 장소를 자세히 밝히지 않았지만 아마도 2020년 12월에 s300 v4 를 설치한 이틀후 푸 섬으로 추측하고 있습니다 러시아 언론에 따르면 이번 지대공미사일 훈련에서는 적기가 러시아 영공을 침입했다 고 가정한 상태에서 훈련을 실시했다 고 전했습니다 물론 러시아 언론에서 는 적국이 어느 국가인 지 정확하게 표현 하지는 않았습니다 그러나 누가 봐도 러시아의 적국이 일본 이라는 사실을 쉽게 확인할 수 있었습니다 지정학적 위치상 쿠릴 열도 4개의 성은 경제적인 문제를 떠나 일본의 국방과 안보를 심각하게 위협할 수 있을 정도로 일본과 매우 가깝습니다 따라서 이러한 지정학적 위치 때문에 쿠릴 열도에 관심이 가장 많은 국가 넨 사실상 일본 이라고 할 수 있는데요 그런데 러시아는 현재 쿠릴 열도 4개의 섬 에 대한 반한 문제로 인해서 일본과 첨예하게 갈등을 겪고 있습니다 일본엔 1855년 무역 및 국경 조약 을 언급하며 쿠릴 열도의 남쪽 섬 이 니트룩 구성 쿠나 씰의 섬 식고 탄 솜 합 엄마의 섬 등 내게서 뭘 일본 소유라고 주장하고 있습니다 그러나 러시아는 쿠릴 열도 네 개의 섬은 2차 세계대전 이후 소련의 적법하게 귀속되어 따고 주장하고 있습니다 그러면서 제 2차 세계대전 전승 구긴 러시아와 해 전국 인 일본의 배상 문제를 규정한 1951년 샌프란시스코 강화 조약 에 따라 합법적 으로 러시아의 귀속되어 따면서 절대로 반할 수 없다는 입장을 고수하고 있습니다 따라서 4개의 성은 의심할 여지없이 러시아의 소유라는 것이 며 현재도 러시아가 실효 지배하고 있습니다 그런 자 일본은 최근에도 여러 차례 러시아에게 쿠릴 열도 4개의 섬 에 대해서 반환을 요구하는 등 러시아 를 향해 계속해서 도 발했습니다 그러자 러시아가 일본을 강력하게 응징하게 따는 각오로 일본을 사실상 적국으로 가정하고 지대공 미사일을 발사한 것으로 보입니다 따라서 러시아 언론에 따르면 이번 훈련을 통해 목표물을 탐지하고 식별 그리고 추적하는 등 적국이 침입했다는 가정하에 시뮬레이션의 의 일환으로 지대공 미사일을 발사했다 고 발표했습니다 s300 v4 의 지대공 미사일은 탄도 미사일과 항공기 등에 대한 요격 능력이 매우 높은 것으로 알려져 있습니다 또한 4 거리는 대략 400km 라고 발표했습니다 물론 어느 국가나 미사일을 발사하며 군사훈련을 실시할 수는 있습니다 하지만 지정학적인 위치 가 문제인데요 이번에 러시아가 지대공 미사일을 발사한 것으로 보이는 이 트 루 푸 성은 사실상 일본의 앞마당 이라고 할 수 있을 정도로 일본과 매우 가까운 지역이어서 일본 정부의 긴장도가 매우 높은 것으로 보입니다 이처럼 러시아가 일본을 향한 강력한 메시지는 이뿐만이 아니었습니다 최근 일본이 쿠릴 열도에 대한 도발을 계속하자 러시아는 일본을 향해 본때를 보여 주겠다며 쿠릴열도 에서 군사훈련을 대규모로 늘렸습니다 러시아 언론에 따르면 2019년 4월에 러시아 국방부가 쿠릴 열도 중 하나인 흐 나 씰의 섬에서 반공 전투 임무 구역이 도입되었다 고 발표했습니다 러시아가 일본을 향한 강력대응 은 이뿐만이 아닙니다 러시아 질의 학회 대표들이 쿠릴열도 가 없는 러시아 영토 이미지에 대해서 행정적인 책임을 확립하는 법안을 준비하고 있습니다 러시아 지리 학회 대표 들에 따르면 이지아는 일본의 지도 침략에 대한 대응이라고 명확하게 밝히고 있습니다 지난해 11월에 일본에서는 사진전을 통해 쿠릴 열도 4개의 섬 에 대해서 홋카이도 관광과 관련된 책자가 일본인들을 향해 배포가 되었습니다 사실상 일본 정부가 쿠릴열도 4개의 섬이 일본의 소유라고 주장한 것인데요 일본이 이처럼 쿠릴열도 4개의 섬 에 대해서 지도를 왜곡하지 자 이에 대한 책임과 지리적 용어를 잘 머스 난 책임에 대해 러시아가 작정하고 벌금을 책정 하게 따는 법안을 준비하고 있는 상황입니다 이뿐만 아니라 일본이 도발을 계속하자 최근까지도 쿠릴 열도 에서 대규모 사격 훈련을 하는 등 러시아가 일본을 향해 따끔하게 경고 않은 상황이 계속되었습니다 그러자 일본 엔 여러 차례 쿠릴 열도 해서 러시아가 군사력을 강화하고 사격 훈련을 하는 것은 일본 정부의 입장과 넨 매우 상충 된다 며 강력하게 항의하고 있습니다 이와 더불어 일본 외무성이 주일 러시아 대사관에 도 강력하게 항의해 했는데요 하지만 러시아는 일본의 요구를 철저하게 묵살하고 오히려 더욱 강경한 자세를 취하고 있습니다 지난해 12월 15일에도 러시아 정보 수집기 1대와 러시아 항공기 8대가 동해와 태평양 을 왕복하며 일본을 위협했습니다 그리고 일본 2항의 하면 할수록 더욱 많은 사격 훈련을 실시하고 있는 것으로 보이는데요 지난해 12월 달에는 16일과 23일 그리고 30일까지 무려 세 차례나 사격 훈련을 실시해 일본의 코를 납작하게 만들었습니다 또한 지난해 러시아의 푸틴 대통령은 쿠릴 열도를 발전시키기 위해서 관세 등을 면제하는 특별구 를 창설 한다고 발표했습니다 극동 블라디보스토크에서 개최된 러시아 정부 주최 에 동방 경제포럼 전체회의 에서 밝힌 것인데요 사실상 러시아가 일본을 향해 쿠릴 열도 4개의 섬을 완전히 포기하라 낸 무언의 압박으로 보입니다 또한 최근 일본에서는 또다시 정말 황당한 오류가 발생해 일본인들이 매우 큰 불편을 겪고 있는데요 일본에서도 최근 지하철역에 ic 카드 식 물품 보관소가 설치 되었습니다 그런데 놀랍게도 절도 가 많이 발생해 논란이 되고 있는데요 그 이유는 ic 카드 씩 물품 보관소에 오류가 발생한 것이 원인으로 지목되고 있습니다 정말 일본의 디지털 기술이 또다시 형편 없다는 사실이 드러난 것인데요 일본의 지하철역에 있는 ic 카드 식물 풍 보관소에서 사용자가 잠금장치를 하기 전에 사용가능 램프가 꺼지는 심각한 오류가 발생한 것입니다 따라서 사용자들은 사용가능 램프가 꺼지자 잠겨 있다고 착각하는 경우가 많았다고 하는데요 그로인해 물품 보관소에 나 커가 잠겨있지 않은 경우가 많아 절도 가 많이 발생했다는 것입니다 특히 이러한 ic 카드 식물 풍 보관소를 제조한 일본 기업에 따르면 같은 타입의 락커가 도쿄와 오사카 등 주역 에 설치되어 있다 고 언급하자 일본 경찰들은 주의를 호소하고 있다 고 전했습니다 물품 보관소에 가장 기본중에 기본이 잠금 기능인데 일본에서는 그 잠금기능 조차 제대로 작동되지 못한 사태가 드러난 것인데요 이처럼 일본에서 디지털 기술의 심각한 오류 때문에 일본 기업의 디지털 기술에 대한 불신이 더욱 커져서 일본인들이 여전히 아날로그 방식을 선호하는 것으로 보입니다 은 일본이 쿠릴 열도를 반환 해달라며 러시아를 계속 도발하고 있습니다 그러자 러시아는 지대공 미사일을 발사하는 등 일본을 사실상 적국으로 가정하고 강력하게 응징한 것으로 보입니다 최근 일본은 독도를 향해 강력하게 도발하고 있습니다 대한민국 역시 일본이 도발하면 도발 할수록 일본을 향해 더욱 강력하게 대응해야 할 것으로 보입니다 러시아가 일본을 향해 강력히 응징한 것에 대해서 시청자 님들의 생각은 어떠신가요 오늘 준비한 영상은 여기까지입니다 시청자 님들 항상 건강하시고 복 많이 받으세요
#
# 🔷 영상 요약 전 후
# 러시아가 실효 지배하고 있는 쿠릴열도 에서 러시아가 지대공미사일 s300 v4 발사 훈련을 실시했다고 러시아 정부가 밝혔는데 이는 일본의 군사적인 위협을 느낄 수 있는 것으로 보이는데 러시아는 현재 쿠릴 열도 4개의 섬 에 대한 반한 문제로 일본과 첨예하게 갈등을 겪고 있습니다
#
# --------------------------------------------------
# Sample 858
#
# 🔶 영상 요약 전
# 오 노캔  잘하시네 안녕하세요 이사입니다 드디어 제가 원했던 기다리고 기다리고 기다렸던 노이즈 캔슬링 헤드폰이 새롭게 출시했습니다 한국에서도 매년 특히 겨울철 오버이어 노이즈 캔슬링 헤드폰의 사용자가 점점 늘어가고 있고 개인적으로 노이즈 캔슬링이 하면 보스가 떠오는만큼 보스의 노이즈 캔슬링 신제품을 저는 좀 기다려 왔습니다 왜냐면 보스도 QC 3라는 노캔 헤드폰이 2016년에 출시했고 이후 새로운 제품이라기보다는 제품들 뭐 이제 QC 45와 같은 요러 제품이 출시해서 좀 아쉬웠는데 2023년 9월 14일 진짜 새로운 디자인을 가진 신제품이 공개되었습니다 그래서 저도 한국 정발 하기 전에 미리 받아서 보스의 QC 울트라 언박싱 그리고 첫인상을 이야기해 보려고 해요요 제품은 완전 완전히 이제 QC 제품의 후속작이라 그보다 많은 사람들이 알 수도 있지만 모를 수도 있는 NC 700이 모델의 후속작 격이기 하거든요 어찌됐든 보스에서 오랜만에 출시하는 제품이라 관심도가 많은 제품이고 그리고 신기했던 건 글로벌 런칭가 429달러 단순히 우리가 부가세 포함해서 계산해도 한 63만 원이라서 와 이거는 좀 쉽지 않겠는데 했는데 한국의 정말한 가격은 49만 99,000원에 출시했습니다 보스가 한국에 웬 일이래요 자 언박싱할 수 있는요 테이프는 여기 있는데 제가 아까 전에 던져 받으면서 이게 미리 좀 떼어 버리긴 했어요 근데 박스는 기존 제품과 크게 차이가 나지 않는 거 같은데요 그만 이제 좀 특징이 있다면 이제 각종 인증들을 좀 많이 받았더라고요 메이드포 아이폰과 아이패드 인정도 받았고 뭐 안드로이드 그리고 심지어 스냅드래곤 사운드 인증까지 받은 제품입니다 뭐뭐 각종 인증을 받았다 뭐요 정도까지 하고 자 구성품은 어 요것도 살짝 잡아서 들어올릴 수 있게 만들어놨네 이렇게 들어올리면 안쪽에 우 와 나는 개인적으로 보스의 파우치가 좀 마음에 들어 파우치도 엄청 흐물흐물 하잖아요 그럼 보관하고 들고 다닐 때도 불편한데 파우치는 고급스러운 느낌이 확 들어요 화이크 스모크는 때가 좀 탈 것 같지만 오 그래도 되게 예쁩니다 부성 부은 여기 다 들어 있어요 여기 보면 어 안쪽에 오 케이블 두 개 들어 있네 보스는 특이하게이 케이블의 특징이 뭐냐면 일반적인 3.5파이 케이블을 주지 않더라고요 한쪽은 3.5 한쪽은 2.5파이 오디오 케이블을 주고요 a2c 케이블도 함께 들어 있습니다 오 케이블 퀄리티가 의외로 좋네 오 케이블 퀄리티가 괜찮아요 그리고 오른쪽에 봉 anche 보스 QC 울트라 오랜만에 나온 신제품이 들어 있습니다 헤드폰을 접을 수 있게 들어 있어서 되게 콤팩트하게 들고 다닐 수 있게 되어 있구나 색상은 화이트 스모크 밝은색이 있고요 또 하나는 블랙 두 가지의 컬러로 출시했습니다 제가 미리 써본 컬러는 블랙이고 사실 저는 이렇게 이제 노캔 헤드폰이 예전에 유행하지 않을 때는 밖에서 쓰고 다니기 약간 민망해서 블랙이 좋았지만 이제는 많은 사람들이 노캔 헤드폰을 많이 쓴단 말이에요 그렇다 보니까 이제는 좀 당당해져 저는 요런 이제 밝은 톤의 헤드폰을 더 좋아하는 편입니다 그리고 디자인도 많이 바뀌었습니다 보스의 투박한 디자인에서 많이 세련된 깔끔해진 느낌이랄까요 예를 들어 이것과 부분에도 아무것도 없이 버스 로그만 있고 되게 깔끔하죠 QC 45는 오른쪽 유닛에 요렇게 이제 전원 온오프 그리고 블루투스 페어링 버튼이 있었지만 곳이 사라지고 하단에 버튼이 생기면서 이어컵 부분에서는 되게 깔끔한 디자인으로 모두 변경이 되었습니다 그렇다 보니 일주일 가량 사용하면서 좋았던 점은 고급감이 더 좋아졌다는 것 그래서 이게 왜 이렇게 고급감이 이런 버튼들로 숨겨서 더 좋아졌나 이런 생각을 했는데 전체적으로 보면 나사를 눈에 보이지 않는 것으로 많이 숨겼더니 곳에 이렇게 곳곳에 박혀 있기 때문에 뭔가이 전자 제품이라는 느낌이 있잖아요 하지만 울트라는 안쪽에 눈에 잘 보이지 않는 곳에 숨기면서 되게 깔끔한 디자인으로 좀 더 고급스럽게 만들었다라는 될 것 같습니다 아 그것도 있다 길 조절 할때도 좀 달라요 기존은 요렇게 조절했어요 울트라는 약간은 경박 hel 수 있는 소리에서 부드럽게 길리 조절할 수 있게 바뀐 것 이렇다 보니까 전체적인 경험에서 더욱 고급스럽게 느껴졌습니다 휴대성을 위해 기존과 마찬가지로 접히는 디자인도 유지를 했고 렇게 돌아가기도 해요 또 좋았던 점도 있습니다 원래 이어컵 부분이 기존 제품들은 요것을 분해하고 탈부착 시키기가 좀 많이 어려웠거든요 하지만 이번에는 조금 더 쉽게 빼고 장착할 수 있도록 바뀌었고요 이어컵은 사실상 이제 좀 만져 보면 얘가 전작보다는 더 매트해습니다 그래서 이제 조금 사용해 보면 주름이 더 많이 지기도 해요 나머지 포트들은 C 타입이 왼쪽으로 옮겨 졌고요 볼륨 조절은 터치식으로 바뀌었습니다 튀어 나와 있는 부분에 터치로 내리거나 올리면서 볼륨 조절할 수 있게 바뀐 깔끔한 디자인으로 변경되었습니다 다음은 착용감 보스 헤드폰이 착용감이 좋기로 되게 유명해요 그래서 이제 착용감을 한번 보여 드리자면 블랙 화이트 스모크 요거 또 QC 4호랑 비교한다면 확연한 차이가 존재했어요 외관적인 부분은 헤어밴드 윗부분이 좀 하드한 소재로 바뀌었거든요 안쪽에 메탈이 있을 수도 있고 좀 단단한 소재로 바뀌었고 아래쪽에는 엄청요 쿠션감이 두툼하게 있어서 부드럽고 푹신한 소재로 변경되었습니다 그래서 이제 오랫동안 착용했을 때 특히 헤어밴드 그 머리 윗 부분으로는 압박되는 느낌이 전혀 없었고요 귀에 닿는 부분은 안쪽으로 감기는 느낌이 있는 그런 착용감이 있습니다 원래 귀에 착용하자아요 그럼 다른 제품들은 부피를 줄이기 위해 안쪽이 되게 평평하게 되어 있단 말이에요 그렇게 되면 귀에 닿았을 때 귀가 드라이버에 닿을랑 말랑하면서 또 움직이면 요게 착착착착 렇게 닿아서 살짝 거슬리거나 보스는 고런게 없어요 이유는요 요거를 빼보면 알 수 있는데 지금 여기 보면 평평하지 않고 드라이버가 귀 방향에 맞게 안쪽으로 들어가 있기 때문에 착용했을 때 드라이버가 귀에 닿지 않아서 요것도 느낌이 되게 좋아요 착용시의 밀착 값은 QC 4호와 비교했을 때 크게 차이가 나지는 않지만 울트라가 조금 더 밀착력이 좋아진듯한 그런 느낌이 들기도 했습니다 이렇게 밀착력을 조금 계산했다는 건 고역대의 노캔 성능을 위해서 계산한 느낌이랄까요 그러니까 이제 정확하게 착용감 느낌이 어떠냐면 자 QC 사워를 했을 때 전체적으로 안으로 밀리도록 쪼이는듯한 느낌이라면 울트라는 헤어밴드 부분이 달라지면서 뭔가이 위쪽에서 좀 압박되는 느낌이 살짝 줄어들었습니다 근데 쓰다 보니 좀 이제 묘한게 뭐냐면 이어 쿠션이 좀 바뀌었다고 했잖아요 요게 묘하게 인조가죽의 느낌이나요 그래서 살짝 부드러우면서 살짝 딱딱함을 바뀐듯한 느낌이 들었기 때문에 저는 저어도 도이 착용감은 새로운 버전이 더 좋지만 이어컵 부분의 그 쿠션 느낌은 기존 버전이 더 좋게 느껴졌습니다 얘는 꽤 쓴 건데도 되게 부드러워요 차이가 많이 나는데요 아 그것도 있다 요거는 착용감이 아니라 사용성에 관한 문제인데 기존 모델들은 착용 감지 센서가 없어서 착용을 하나 벗어나 뭐 노래 일시 정지라는 자동 꺼진 기능이라든지 요런게 없었는데 새로운 버전은 착용 감지 센서가 들어갔기 때문에 벗으면 일시 장지 착용하면 재생 전원을 자동으로 온오프하는 기능이 새롭게 추가 되었더라고요 그것도 뭐 온오프 할 수도 있고요 다음으로 많이 궁금해하실 부분이 노이즈 캔슬링이 라고 생각해요 야 역시 보스가 노캔 맛집이 맞긴 맞아요 이전에도 그거 있잖아요 보스 QC 이어버드 2가 나왔을 때도 노캔 성능이 죽여 준 것처럼 QC 울트라 또한 노캔 성능이 훌륭했습니다 이게 또 어떤 차이점이 있냐면 아 이게 자꾸 QC 4호랑 비교하게 되는데 전체적인 느낌은 물리적으로 미세하게 고역대의 노이즈를 조금 더 차단을 더 잘해주고 저역대의 성능이 더 강화된게 체감되었다 특히 길가다가 요즘 오토바이가 많잖아요 오토바이 지나갈 때 노이즈 삭제 정도가 확실히 체감될 정도 카페에서도 노캔 성능을 체감할 수 있었어 니다 고역 대는 어쩔 수 없이 노이즈가 좀 많이 들어오는 편이긴 하지만 이제는 저역대는 웬만하면 거의 걸러 준다는 정도로 발전했다 랄까요 대충 서음이 어느 정도로 들어오냐면 이제 저 ...
#
# 🔷 영상 요약 전 후
# 보스도 QC 3라는 노캔 헤드폰이 2016년에 출시되어 새로운 디자인을 가진 신제품이 공개되었고 저도 한국 정발 하기 전에 미리 받아서 보스의 QC 울트라 언박싱 그리고 첫인상을 이야기해 보려고 합니다.
#
# --------------------------------------------------
# Sample 4011
#
# 🔶 영상 요약 전
# 1월 16일에 3m 에 달하는 거대한 해일이 일본을 덮칠 것으로 전망하고 있습니다 따라서 일본은 지금 다급하게 긴급 사태를 발령 해 1월 16일 새벽부터 대피하는 소동이 벌어지고 있는 등 그야말로 난리가 나고 있습니다 1월 15일에 10만명 정도 살고 있는 태평양에 통과 왕국 부근에서 엄청난 해저 화산이 폭발해 평양 부근에 살고 있는 국가도 뿐만 아니라 일본에까지 엄청난 영향을 끼치고 있다는 소식이 들렸습니다 통과 당국에 따르면 1월 15일에 수도 누크 1로 파 에서 북쪽으로 65km 해역에 있는 화산에서 거대한 폭발이 발생했다 고 전하며 통가 왕국의 힐 경보를 다급하게 발명했습니다 통과 왕국의 살고 있는 주민들의 따르면 화산 폭발로 인해서 하늘이 모두 검게 변했고 화산 제가 하늘에서 5 수수 떨어졌습니다 그리고 지금까지 전해진 바에 따르면 그와 동시에 1.2m 에 달하는 거대한 해일 까지 통과 왕국을 덮쳤다 고 전했습니다 따라서 수만 n 통과 사람들이 고지대로 다급하게 피신 햇다고 하는데요 거대한 해저 와선 폭발로 인해 호주와 뉴질랜드 피지 등 다수의 남태평양 국가들에서도 유사한 해에 경보가 발령된 였습니다 그런데 이러한 헤이리 머나먼 일본의 까지 도달할 것으로 보입니다 일본의 방재 과학기술 연구소 화산 연구 추진 센터 나카타 센터장은 통과해 저와 선 폭발로 인해서 화산재가 무려 20km 까지 치솟았다 고 설명했습니다 이뿐만 아니라 화산재가 무료 260 km 까지 퍼질 정도로 엄청 났다고 하는데요 이번에 통과해 저와 선 폭발은 1991년 필리핀 피나투보 화산 폭발과 비슷하다 고 말하며 피나투보 화산 폭발 때 분출 물이 성층권 으로 대량 방출 되고 햇빛이 가려 지면서 세계적으로 기운이 떨어졌다 고 설명했습니다 그리고 피나투보 화산 폭발 후 2년 뒤에는 기록적인 추운 여름이 찾아 왔고 그로 인해 일본에서 살롱 4대 6년이 들어 태국에서 쌀의 긴급 수입한 의 사태도 발생했다 고 전했습니다 그만큼 일본에 끼친 영향이 매우 컸는데요 하지만 피나투보 화산은 북반구 인 반면에 이번 폭발은 남반구에서 발생했기 때문에 향후 에 어떠한 영향이 있을지 아직까지는 모르겠다 는 입장을 일본의 전문가들은 전하고 있습니다 따라서 향후 의 상황을 김미리 주시할 필요가 있다며 긴장의 끈을 놓지 않고 있습니다 그러나 이번 통과해 저와 선 폭발이 워낙 거대해 있기 때문에 주변에 뿌려진 경 속에 피해가 우려될 것으로 알려졌습니다 특히 최근에 해저 화산이 분출한 일본의 오가사와라 제도의 후크 토크 카노 바와 같이 대량의 경 속에 의한 피해가 발생할 가능성이 크다는 것입니다 그러면서 이번에 분출 양은 호쿠토 코카 노바 보다 훨씬 많아 주변 국가의 광범위하게 피해가 발생할 것이라고 전했습니다 그리고 통과 화산 폭발은 일본 에도 영향을 끼치고 있습니다 이미 일본은 지난 1월 15일 20시 부터 21시까지 일본 전국에서 일시적인 기압 변화가 찾아왔습니다 통과해 저와 산이 폭발했을 때 충격파가 일본의 도달 했기 때문인데요 다음 보시는 그래프가 일본의 기압 변화를 나타내는 것입니다 일본의 기압 변화 낸 간토 지방과 이즈 제도 등 일본의 남동쪽 에서 부터 시작되었습니다 그리고 일본 전국 3000개 소의 설치한 관측기 에 따르면 기압 상승이 발생한 뒤에 곧바로 기압이 하강 안의 상황이 발생했습니다 이것은 충격파에 따른 특유의 기압 상승과 기 아파 강으로 파악되고 있습니다 물론 이번 충격파에 의해서 어떤 피해가 발생하지는 않을 것으로 보이지만 이번 통과에 저와 선 폭발이 얼마나 큰 것인지 나타내는 지표로 보입니다 하지만 직접적인 영향을 끼치는 것도 있습니다 바로 거대한 해일이 인 데어 남반구에서 발생한 해저 화산 폭발이 지만 일본에도 거대한 해일이 밀려오고 있습니다 일본 기상청은 1월 16 의 새벽에 다급하게 남태평양 통가 제도의 화산 폭발에 의해서 해 일과 관련된 브리핑 을 개최하고 지진에 따라 발생한 앤 통상적인 해 외관 n 다르다 고 밝혔습니다 일본 기상청은 당초에 일본에서 약간의 해수면 변동 은 있어도 헤이 피해낸 전혀 없을 것이라고 발표 했었습니다 그러나 상황이 급반전 되고 있는데요 지진에 의해서 수반에 발생하는 통상의 힐과 이번 해저 와선 폭발의 해일이 전혀 다르다 면서 한 번이 아니라 여러 번에 걸쳐 거대한 해일이 일본으로 밀려 오고 있다고 경고했습니다 일본 기상청은 이러한 사례는 처음 이라면서 다급하게 발표했는데요 이번해 일은 상당한 기간동안 여러 번에 걸쳐 발생할 것으로 생각합니다 어떠한 일이 발생하고 있는지 전문가들 조차 파악하지 못하고 있습니다 따라서 지금은 새벽이라 어둡기 때문에 바다 쪽에 살고 있는 일본인들은 당장 바다 근처에서 대피 해주시길 바랍니다 라고 강력하게 대피를 호소했습니다 그러면서 날이 밝아도 헤이리 계속해서 밀려 들어올 가능성이 높기 때문에 바다로부터 확실히 멀어져야 하며 해일 경보 가 해제될 때까지 안전한 장소에서 절대 벗어나지 말라 라고 견고하며 계속해서 일본인들을 향해 피난 이나 경계를 호소했습니다 따라서 태평양 연안에 있는 수많 n 일본 지자체가 새벽에 사이렌 을 올리며 경보를 발령 했습니다 일본의 총무성 수 방청 에 따르면 1월 16일 새벽 3시 45분 경에 아오모리 이와테 미야기 지바 고치 미야자키 가고시마 등 8개 연에 대해서 대피 지시가 발령 되었습니다 현재까지 대상이 되고 있는 일본인들은 101,000 세대로 대략 213,000 400명으로 보이며 즉각 피난 빌딩이나 고지대 등 안전한 장소로 대피 하라고 경보를 발령 했읍니다 일본 해상보안청 역시 경보를 발령 했는데요 일본의 태평양 부근에서 위험 물이 필요하거나 해수면의 상당한 변화 등으로 항만 이나 항로 표식 등이 피해를 입을 가능성이 크다 며 일본의 태평양 연안을 항해하는 선박은 특히 주의를 해야 한다 고 밝혔습니다 현재 1월 16일 새벽 4시까지 일본 기상청이 힐을 관측한 바는 다음과 같습니다 후쿠시마 현에서 는 1월 15일 오후 11:54 의 0.7m 의해 일이 발생했습니다 미야기 현에서 는 15일 오후 10:59 의 0.6m 헤이리 발생했고 이바라키 현에서 낸 15일 오후 11:57 의 0.5m 해이 지바 현에서 낸 15일 오후 11:44 의 0.3m 헤이 와카야마 연에서 는 16일 오전 0:31 의 0.9m 해외 고치현 에서는 16일 0:23 의 0.9m 의해 일이 발생했습니다 이와 태연 에서도 16일 0시 3분 에 0.9m 해이 씨즈 오카 에서 낸 16일 0시 16분에 0.7m 의해 일이 발생했습니다 이처럼 일본 태평양 연안 대부분이 큰 영향을 받고 있지만 이것은 시작에 불과할지도 모른다는 불안감이 커지고 있습니다 일본 기상청에 따르면 장소에 따라서 앞으로 더욱 큰 해일이 도달할 우려가 크다 고 경고한 것입니다 일본 기상청은 이번 해일은 지진으로 인해 발생한 해일과 달리 창당한 기간 동안 여러 번에 걸쳐서 헤이리 도달할 우려가 있다면서 무려 3m 에 달하는 거대한 헬 도 예측했습니다 현재의 일본 기상청에 따르면 앞으로 예상되는 해일의 높이는 다음과 같습니다 홋카이도 아오모리 현 미야기현 후쿠시마현 이바라키현 지바 현 시즈오카 연 아 이치원 미 현 와카야마 현 도쿠시마 현 고치 원 미야자키 현 가고시마 연등 일본 태평양 연안 대부분이 제일 파가 도달 한 상태이며 앞으로 1m 에 달하는 거대한 해일을 전망했습니다 그리고도 카레 열도 y 와 태연의 경우에도 이미지 재입학 아 도달한 상태이며 앞으로 무려 3m 에 달하는 거대한 해일이 발생할 것이라고 전망하며 더더욱 주의를 요구하고 있습니다 현재의 일본 기상청에 따르면 언제 힐 경보가 해제 될지 모르겠다며 일본인들을 향해 계속해서 안전한 장소에 반드시 머물러 있어야 한다고 강조했습니다 다행히 통과에 저와 선 폭발로 인해 한국에는 헤이 피해가 발생하지 않을 것으로 보여 천만다행으로 보입니다 앞으로 일본에서 헤일 과 관련된 소식이 들리면 최대한 빠르게 전해드리도록 하겠습니다 정말 안전이 제일 중요한 것 같습니다 시청자 님들 항상 건강하시고 복 많이 받으세요
#
# 🔷 영상 요약 전 후
# 1월 15일에 3m 에 달하는 거대한 해일이 일본을 덮칠 것으로 전망하고 있는 가운데, 통과 당국에 따르면 1월 15일에 수도 누크 1로 파 에서 북쪽으로 65km 해역에 있는 화산에서 거대한 폭발이 발생했다고 전하며 통가 왕국의 힐 경보를 다급하게 발명했다고 전했다.
#
# --------------------------------------------------
# Sample 5440
#
# 🔶 영상 요약 전
# 현재 토트넘의 분위기가 심상치 않습니다 여러가지 악재가 쌓이고 쌓여 폭발하기 직전입니다 이런 상황에서 히샬리송의 작심 발언마저 터지고 말았습니다 대체 무슨 일이 벌어지고 있는 건지 생생큐브에서 자세한 소식 전해드리겠습니다 대한민국의 손흥민 선수 최근 유력 축구 언론들은 손흥민에게 이런 수식어를 붙였습니다 세계 최고의 선수를 가리는 발롱도르 시비리의 당당히 이름을 올리면서 아시아 선수 역대 최고 기록을 갱신한 프리미어리그의 레전드라고 말입니다 하지만 이런 수식어가 무색하게도 토트넘 내부 상황은 최악을 향해 달리고 있습니다 토트넘은 곧 뉴캐슬과 대결을 펼치게 되는데 리그 최소 시점을 기록하며 6경기째 무패 행진을 달리고 있는 뉴캐슬을 상대로 제대로 된 경기를 펼칠 수 있을지 걱정이 될 정도입니다 손흥민은 직전 경기인 맨체스터 유나이티드전에서 단 한 차례의 슈팅을 기록하며 아쉬운 경기를 치렀고 뉴캐슬 전 득점을 통해 자존심을 되찾고자 합니다 프리미어리그 통산 96골을 기록 중인 손흥민은 백골을 향한 득점포 재가동에 나서고 지난 9월 레스터 해트트릭 이후 리그 4경기 동안 득점을 올리지 못하고 있는 손흥민은 이번 홈경기에서 골 감각을 끌어올리기 위해 벼르고 있을 것입니다 토트넘은 신기하게 팀 성적은 좋습니다 토트넘은 메뉴한테 거의 산산조각이 나며 자존심을 구겼으나 3위를 지키는 데는 성공했습니다 하지만 첼시와 맨유 뉴캐슬의 바짝 추격을 당하고 있는만큼 승리를 통한 상위권 유지에 신경써야 할 상황이고 3위의 경기력을 보여주지 못하고 있다는 것에 주목해야 합니다 대양 쿨루셉스키와 히샬리송이 부상으로 출전이 어려워 결국 득점을 통한 토트넘의 승리를 위해서는 송캐디오 손흥민과 해리 케인이 나서야 합니다 토트넘이 반등하기 위해서는 수비 안정도 중요하지만 무엇보다 공격에 파괴력이 필요합니다 토트넘은 올 시즌 모든 대회를 통틀어 15경기에서 16골을 내주는 불안한 수비에도 불구하고 좋은 성적을 유지할 수 있었던 것은 그나마 공격진이 잘했기 때문인데 최근 이상한 전술 때문에 공격력이 다시 시들고 있습니다 토트넘 공격이 힘을 내기 위해서는 손흥민의 활약이 절실하고 바꿔 말하면 콘테가 정신을 차려야 합니다 지난 시즌 epl에서 23골을 터뜨리며 득점왕에 올랐던 손흥민은 계속 동료들로부터 지원을 받지 못하면서 고립되고 있습니다 오죽하면 국내 매체뿐 아니라 영국 더미러 메트로 스포츠몰 스포츠 바이블 등 일련의 매체들이 손흥민의 희생을 대서특필하고 있고 프리미어리그 레전드들은 하나같이 손흥민을 응원하고 있습니다 풋볼데일리가 올린 EPL 레전드들의 손흥민 오모바라는 내 시간만에 수십만 뷰를 돌파했고 팬들의 뜨거운 관심을 반영했습니다 팬들은 해당 영상과 기사 아래 손흥민과 헤리케인은 토트넘을 떠나야 한다 토트넘은 콘테를 경지라고 새로운 감독을 데려와야 한다 콘텐츠 경기를 포기했고 이미 트로피를 들어올릴 멘탈이 없음을 보여준 것이다 이번 시즌 최악의 결정 중 하나였다 손흥민이 토트넘을 떠날 수도 있을 것 같다는 생각이 든다 한 번도 우승하지 못하고 떠나게 되면 실망스러울 것이다 그의 커리어를 토트넘에서 낭비했다는 생각에 가슴이 아프다 케인과 손흥민은 더 좋은 팀에 갈 수 있는데도 여전히 토트넘에 있다 등의 댓글을 쏟아냈습니다 손흥민 희생당하고 있는 것에 분노를 느끼고 있는 것은 팬들뿐만이 아닙니다 영혼의 파트너인 케인도 그리고 최근에는 히샬리송까지도 강한 분노를 느끼고 있다는 소식이 전해지고 있습니다 손흥민의 빅 팬이라고 밝히기도 한 히샬리송은 토트넘에 올 때부터 손흥민에게 모든 존중을 보냈습니다 둘은 경쟁관계에 놓여 있는데도 불구하고 손흥민이 레스터시티점 부활에 신호탄을 썼을 때 히샬리송은 경쟁상대인 손흥민의 진심으로 축하하는 모습을 보여줬습니다 히샬리송은 같은 날 자신의 sns에 소니의 해트트릭 내 형제 정말 축하해라고 적은 게시물을 올렸고 손흥민에게 직접 사인을 받은 유니폼도 함께 올릴 정도였습니다 손흥민 역시 히샬리송을 잇는 그대로 존중했습니다 생애 처음으로 히샬리송이 챔피언스리그에서 멀티골을 뽑아내고 눈물까지 보였을 때 손흥민은 자신의 sns에 특별한 선수 히샬리송을 위한 특별한 밤 엄청난 분위기였습니다라며 히샬리송을 진심으로 축하하는 글을 올린 적이 있습니다 이처럼 두 선수는 서로의 성품과 실력을 존중하고 손 경쟁은 항상 좋다 경쟁은 나뿐만 아니라 팀 동료들도 향상시킨다 히샬리송과 같은 선수를 영입한 건 대단한 일이다 히샬리송은 훌륭한 선수이기엔 난 그의 영입을 반긴다 같이 생활한지 얼마되지 않았지만 정말 친한 친구 사이가 됐다라고 밝혔습니다 하지만 히샬리송은 현재 토트넘에서 수비하는 손흥민의 모습을 보며 충격에 빠졌습니다 토트넘 내부 관계자에 의하면 히샬리송이 토트넘으로 이적을 결심한 가장 큰 이유는 챔피언스리그에 진출하는 것과 프리미어리그 최고의 공격진으로 평가받던 게임과 손흥민 함께 뛰는 것 때문이었는데 콘테가 손흥민 희생을 강요하고 공격진영에서 손흥민과 제대로 된 호흡을 맞추기 어려운이 상황에 분노를 표출한 것으로 알려진 것입니다 특히 히샬리송은 자신이 존경하는 손흥민이 경기 내내 고립되고 비정상적인 수비가담을 하는 것을 보면서 벤치에서 오랫동안 고개를 숙이고 있었다는 일화가 전해지기도 했습니다 공격진영에서 손켓 듀오와 호흡을 맞추는 것을 고대하고 토트넘에 왔는데 그에게는 이상과 현실의 괴리가 너무나도 심했던 것입니다 최 그녀의 레전드인 하그리브스는 이런 말을 했습니다 누구나 손흥민 케인과 같이 뛰기 바란다 손흥민과 케인은 프리미어리그 빅6와 맞설 수 있는 토트넘의 유일한 공격진이다 그만큼 손켓이오는 선수들에게도 우상인 존재라는 것입니다 한편 이런 상황에서 다소 충격적인 소식이 전해졌는데요 콘테 감독이 재계약을 미루는 이유가 예산 우려 때문이라는 것입니다 영국 풋볼 인사이더는 바로 오늘인 23일 콘택 감독은 이적 예산에 대한 우려 때문에 토트넘에서 새로운 계약을 체결하지 않고 있다라고 전했습니다 콘테 감독은 지난해 11월 토트넘 감독직에 부임했습니다 시즌 도중 부임이었음에도 불구하고 곧바로 팀을 변화시켰습니다 토트넘은 성적이 좋아지면서 순위가 수직 상승했고 경기력 측면에서도 상대를 압도했습니다 결국 목표였던 챔피언스리그 진출권을 획득하는 데에도 성공했습니다 콘테 감독이 토트넘에서 성공가도를 달리고 있지만 팬들은 한 가지가 불안했습니다 바로 그의 계약 기간입니다 당초 콘테 감독은 부임 당시 연장 옵션이 포함되어 있지만 2023년 6월까지 동행을 약속했습니다 즉 계약기간은 올 시즌까지이고 여기에 최근 유벤투스와도 연결되면서 팬들의 불안감은 더 커졌습니다 하지만 영국 풋볼 런던의 알렉스 대학 골드 기자는 1년 연장 옵션이 가능하다고 밝혔습니다 그는 지난 23일 콘택 감독의 계약은 이번 시즌이 끝난 내년 여름이다 하지만 계약을 연장할 수 있는 옵션이 있다 또한이 옵션은 쌍병약 옵션이라는 것인데이는 양 당사자가 연장에 동의해야 한다는 의미다 그러나 토트넘이 선택권을 쥐고 있고 구단은 언제든지 옵션을 발동할 수 있다라고 설명했습니다 즉 토트넘은 원한다면 언제든지 콘택 감독과 1년 재계약을 맺을 수 있다는 의미입니다 만약 토트넘이 계약 연장 옵션을 발동하게 된다면 콘테 감독은 토트넘과 2024년 여름까지 계약 기간이 연장됩니다 토트넘 관계자인 맥매너스는 떠나려는 콘테가 이적의 산 지원을 약속받으면 재계약을 맺을 것이라고 확신했습니다 그는 풋볼 인사이더와의 인터뷰에서 나는 그가 저녁 시장에서 강한 지질을 받고 싶어할 것이라고 생각한다 그들은 예상과 실제 지출할 수 있는 금액 면에서 콘테가 원하는 자금을 조달해야 한다 콘테 감독은 내년 여름 그들이 큰돈을 쓸 것이라는 보장을 내비 회장으로부터 원할 것라고 주장했습니다 이어 최고의 선수들을 영입하기 위해 그 팀에 1억 5천만 파운드 2억 파운드를 써야 한다 나는 그가 그 보장을 받는다면 재계약의 서명할 것이라고 생각한다 나는 콘테 감독이 재계약에 서명하지 않는 이유가 이적 자금에 대해 확신하지 못하기 때문이라고 생각한다 아마도 그는 그의 선수단 깊숙한 곳에서 약간 좌절하고 있는 것 같다라고 덧붙였습니다 내용은 이렇지만 일각에서는 작은 문제는 핑계에 불과하다면서 오히려 콘테가 큰 그림을 그리고 있는 것이 아니냐 ...
#
# 🔷 영상 요약 전 후
# 토트넘은 리그 최소 시점을 기록하며 6경기째 무패 행진을 달리고 있는 상황에서 토트넘은 리그 최소 시점을 기록하며 6경기째 무패 행진을 달리고 있는 뉴캐슬을 상대로 제대로 된 경기를 펼칠 수 있을지 걱정이 될 정도입니다
#
# --------------------------------------------------
# Sample 3934
#
# 🔶 영상 요약 전
#  일본의 수도인 도쿄가 물에 잠길 수 있다는 우려가 있다며 높이 10m에 육박하는 방파제를 건설하고 있어 일본에서 매우 큰 논란이 되고 있습니다 그 길이만 해도 무려 60km의 달할 정도로 거대하다고 하는데요 일본인들은 이처럼 거대한 방파제를 보며 거대한 바벨탑을 만들어 결국 멸망의 이름 바빌론 프로젝트 같다고 우려하고 있습니다 이제 일본 역시 본격적으로 물바다가 될 직접적인 위험에 처한 것으로 보입니다 어떠한 소식인지 자세히 살펴보겠습니다 일본이 올해에도 어김없이 온난화 대책의 가장 뒤쳐진 국가에게 주어지는 화석상을 2022년 11월 9일에 수상해 불명예를 떠안게 되었습니다 환경단체 ngo의 국제네트워크인 기후행 동네트워크가 일본이 기후 온난화 발생원인에 대해서 가장 책임이 있는 일이 국가로 선정되었다면서 강도 높게 비판했습니다 최근 기후위기로 인해 전 세계가 태풍과 폭우 등 기상위변이 자주 발생하고 있습니다 그리고 그 피해가 가장 큰 국가 중 하나 바로 일본입니다 일본은 지난 10여년간 단 며칠 만에 1000mm가 쏟아지는 폭우가 자주 발생하고 태풍이 연이어 강타하는 등 기우재난의 초토화가 되고 있습니다 올해에만 해도 일본의 초강력 태풍과 폭우가 여러 차례 발생했고 그로 인해 일본인들이 큰 고통을 겪고 있습니다 그러나 일본 정부는 기상위변에 근본적인 원인이 되고 있는 화석연료 사용에 대해서는 거의 방치하고 있어 일본 우량한 비판이 거세지고 있는데요 일본 정부가 화석상을 수상한 근거가 있습니다 미국 ngo인 오일 체인지 인터내셔널 보고서에 따르면 일본 정부가 국제협력 은행이나 투자은행과 함께 석탄이나 석유 그리고 천연가스 사업에 투자한 금액이 2019년부터 2021년까지 연평균으로 106억 달러 원화로 무려 15조원에 달했다는 것입니다 기우재난을 직접적으로 경험하고 있는 일본이지만 이러한 화석연료에 대한 비중은 거의 줄이지 않고 있습니다 일본이 화석상을 수상 것은 3회 연속으로 불명예스러운 수상이 되고 있습니다 이에 대해서 일본 언론마저도 불명예스러운 결과라고 한탄하고 있는데요 물론 캐나다와 미국 그리고 한국과 중국도 화석연료에 대한 투자가 많은 편이긴 하지만 일본을 넘어서기 힘들었는데요 따라서 전 세계가 기상위변에 대처하기 위해서 변화를 시도하고 있지만 일본만 거의 유일하게 오히려 시대의 역행하고 있다고 전 세계 경제 전문가와 NGO 단체가 비판하고 있습니다 물론 이에 대해서 중국과 관련된 정보를 믿기 어렵다는 주장도 제기되고 있습니다 따라서 만약 중국 정부가 제대로 된 정보를 공개했다면 중국이 일본을 제치고 화석상을 받았을 가능성이 높다는 주장이 나오고 있습니다 그러나 5일 체인지 인터내셔널 ngo가 중국에 대해서 이러한 사항에 대해서 직접적으로 조사할 권한이 없기 때문에 중국 순위는 예상보다 순위가 낮은 편으로 보입니다 그리고 일본이 지속적으로 화석상을 받을 수밖에 없는 이유가 있습니다 cop27 즉 기후변화협 지구온난화를 방지하기 위해 온실가스를 인위적으로 방출하기 위한 협약을 뜻합니다 일본이 지속적으로 화석상을 받을 수밖에 없는 이유가 있는데요 일본 정부의 방침이 기후변화협약과 완전히 상반되기 때문입니다 기후변화협약에 가장 핵심적인 과제는 석탄화력의 단계적 폐지입니다 그러나 일본은 2030년 이후에도 석탄을 지속적으로 사용할 계획입니다 세계 국가의 노선과 일본의 노선은 완전히 상반된 태도를 보이고 있는데요 지난해 열린 기후변화 협력에서 대한민국뿐만 아니라 46개 국가의 지역이 석탄 화력발전에 대해서 단계적 폐지를 선언하고 지지를 표명했습니다 그러나 일본은 석탄발전이 무려 30%에 달할 정도로 비중이 매우 높음에도 불구하고 여전히 석탄 발전과 관련된 폐지 계획이 없는 상태입니다 이러한 것을 보면 일본 정부의 무책임한 태도를 엿볼 수가 있는데요 그러나 일본 정부가 3회 연속으로 화석상을 수상한 상황에 대해서 일본인들은 정말 황당한 반응을 보이고 있어 논란이 되고 있습니다 정말 이해할 수 없을 정도인데요 영예로운 상입니다 일본 정부가 올바른 에너지 정책을 실행하고 있다는 증거입니다 기후변화가 인위적으로 변한다는 학설은 명백한 허위이자 가짜 과학입니다 이것은 사실 명예로운 일이 아닐까요 화석상을 받을 수 있다는 것은 일본의 탈탄소와 기술의 정당성이 증명된 증거라고 할 수 있습니다 이것은 일본을 위한 상이군요 영광스러운 일입니다 이제 일본은 당당하게 석유와 석탄을 쓸 수 있습니다라는 등 많은 일본인들이 상당히 비상식적인 반응을 보이고 있어 논란이 되고 있습니다 이처럼 일본인들 중에서 상식적이지 않은 반응들이 너무 많아 황당할 정도였는데요 기시다 일본 총리가 왜 기후변화에 대해서 거의 신경을 쓰지 않은지 알 수 있는 대목이었습니다 일본 총리뿐만 아니라 일본인들 역시 지구 온난화에 대해서는 매우 무관심할뿐만 아니라 오히려 화석연료를 사용하는 것을 자랑스러워하는 반응들이 많이 보였습니다 그러나 지구 온난화로 인한 피해를 고스란히 보는 국가 역시 일본으로 보입니다 일본은 섬나라이기 때문에 바다의 영향을 많이 받고 있으며 최근에 태풍과 폭우로 가장 많이 피해를 보는 국가 중 하나입니다 그러한 사례로 일본은 봄부터 가을까지 폭우가 반복되고 있습니다 그리고 일본의 수도인 도쿄 앞에 도쿄만이 있어 더욱 위험하다는 분석이 나오고 있습니다 만약 도쿄만이 태풍이나 해일에 의해서 바닷물이 넘치게 된다면 도쿄가 매우 큰 피해를 볼 수밖에 없다고 일본 정부가 매우 우려하고 있는데요 따라서 일본 정부는 도쿄를 방어하기 위해서 거대한 방조제를 건설하고 있었습니다 그런데 일본 정부가 2022년 11월 10일에 발표한 자료에 따르면 이처럼 거대한 방조제의 높이가 났다고 판단해 더욱 방조제의 높이를 높이는 계획안을 발표한 것입니다 지구온난화가 급격히 진행됨에 따라 일본 앞바다의 해수면이 예상보다 빠르게 상승할뿐만 아니라 초강력 태풍이 자주 발생할 것으로 전망에 초기 방조제 계획안을 수정할 수밖에 없었다고 일본 정부가 밝혔습니다 도쿄도에 따르면 지금까지 도쿄왕 연안에 높이가 최대 8m에 달하며 무려 60km에 달하는 방조제를 설치하고 있었습니다 그런데 2022년 11월 10일에 계획이 변경되어 최대 1.4m까지 더 올리는 계획안이 발표되었습니다 따라서 변경된 계획안에 따라 도쿄형 연안에 최대 높이 9.4m에 길이가 60km에 달하는 거대한 방조제가 설치될 것으로 보입니다 그리고 상황에 따라 해수면에 온도가 더욱 상승할 우려도 있으며 초강력 태풍이 자주 발생할 우려도 있기 때문에 10년마다 계획을 재검토해 방조제를 더욱 높일 수도 있다고 일본 정부는 밝혔습니다 또한 일본 정부에 따르면 폭우와 태풍으로 인해 강수량이 급증할 것으로 보여 도쿄의 배수가 원활하지 못해 침수될 우려가 증가함에 따라 배수펌프를 더욱 많이 설치하는 등 배수능력 향상도 계획하고 있다고 도쿄도는 밝혔습니다 그러나 대해서 일본인들은 최대 높이 9.4m에 길이가 60km에 달하는 거대한 방조제 계획안을 보며 마치 바벨탑으로 멸망한 바빌론 프로젝트 같다라고 우려하기도 했습니다 국제연구팀에 따르면 석탄과 석유 등 화석연료에서 유래하는 2022년 세계 이산화탄소 배출량은 375억 톤의 달할 것으로 추정했습니다 지난해보다 1% 늘어난 수치인데 역대 최대가 되는 것입니다 국제연구팀에 따르면 이러한 원인으로 감염이 줄어 산업이 활성화되는 동시에 세계 각국의 관광 수요가 늘어 항공업계가 되살아나는 영향이 크다고 밝히고 있습니다 2015년 프랑스 파리에서 열린 20일차 기후변화 당사국 총회에서는 세계 각국이 산업화 이전 수준 대비 기온상승을 2도로 제한하는 방안 특히 1.5도 이내로 제한하기 위해서 노력하자는 목표를 세웠습니다 따라서 세계 각국은 온실가스를 감축하기 위해서 노력하고 있습니다 그러나 세계 각국의 노력에도 불구하고 1.5도 이내로 제한하자는 목 달성하기 어려울 것으로 보입니다 특히 일본이 기후 위기를 조장하는 온실가스 배출에 가장 합장 서고 있는 것으로 보입니다 그리고 그러한 피해는 일본에게 직접적으로 영향을 끼칠 것으로 보입니다 이처럼 일본의 어처구니없는 태도에 대해서 어떻게 생각하시나요 오늘 준비한 영상은 여기까지입니다 구독과 좋아요 알림 설정까지 부탁드립니다
#
# 🔷 영상 요약 전 후
# 일본의 수도 수역에 방파제가 건설되어 있어 일본인들은 거대한 바벨탑을 만들어 결국 멸망의 이름 바빌론 프로젝트 같다고 우려하고 있으며 이러한 상황에서 일본 정부는 화석연료 사용에 대해서는 거의 방치하고 있어 일본 우량한 비판이 거세지고 있다.
#
# --------------------------------------------------
# Sample 2388
#
# 🔶 영상 요약 전
# 대한의사협회의 총파업 찬반 투표가 역대 최고 투표율로 마무리됐습니다 서울대를 시작으로 대학 병원들의 집단 휴진 움직임이 확산되는 가운데 환자들의 안전과 생명의 문제를 일으킬 수 있는 결정을 철회하라는 호소도 있다습니다 유서영 기자가 보도합니다 오늘 자정 마무리된 대한 의사 협회 총파업 찬반 투표는 역대 최고의 투표율을 기록했습니다 6월 중 집단 휴진 등 단체 행동에 참여할지를 물었는데 상당수가 찬성했습니다 최근 뒤늦게 공개된 지난해 12월 파업 투표 찬성도 80% 넘어섰던 것으로 알려졌습니다 의협은 내일 개원의와 전공이 의대생 등이 모두 참여하는 대표자 회의를 열고 파업 여부와 시점 등을 정할 방침입니다 가장 압도적으로 높은 투표율을 보이고 있습니다 그만큼 이번 사태 시급한 해결이 필요하다는 회원들의 뜻이 강렬한 것으로 오늘 17일부터 무기한 집단 휴진을 결정한 서울대병원을도록 집단 휴진 움직임도 확산되고 있습니다 성균관대와 고려대 의대 비대위가 긴급 회의를 열었고 가톨릭 중앙의료원 교수들도 주말 동안 의견을 모으기로 했습니다 교수가 가만 있으면 안 되겠다 그런 것도 이제 공감대 형성되고 있는 거죠 계속 아무 반응이 없으면 다른 대학도 움직이겠죠 하지만 의료현장 심은 깊지 있 책임하에 환자와 병원을 방치해서는 안 됩니다 서울대 병원장은 진료가 의사의 첫 번째 의무라면 집단 휴진을 허가하지 않겠다고 밝혔습니다 또 병원을 믿고 다니는 환자들의 불편을 넘어 안전에도 상당한 문제를 일으킬 수 있다며 결정을 철회하라고 요청했습니다 환자 단체들도 집단 휴진은 환자들이 내팽개친 무책임한 행태이다 생명권을 박탈하는 결정이라며 즉각 철회하라고 호소했습니다 MBC 뉴스 유서입니다 l
#
# 🔷 영상 요약 전 후
# 대한의사협회의 총파업 찬반 투표가 역대 최고 투표율을 기록했으며 서울대병원을 시작으로 대학 병원들의 집단 휴진 움직임이 확산되는 가운데 환자들의 안전과 생명의 문제를 일으킬 수 있는 결정을 철회하라는 호소도 있다
#
# --------------------------------------------------
# Sample 4506
#
# 🔶 영상 요약 전
#    계속해서 위클리 픽 시간입니다 오늘 첫 번째 픽은 특별한 손님이 준비했는데요 지금 만나보겠습니다 강하랑 캐스터네 미국은 강력한 한파로 꽁꽁 얼어붙었습니다 극 한파의 영향으로 미국 북부 지역은 체감온도가 무려 영하 51도 아지 아주 크게 떨어졌습니다 그리고 남부 텍사스의 경우에는 보통 겨울철에 따뜻해서 기운이 영하로 잘 떨어지지 않는데요 지난 14일 영하 11도까지 떨어졌고요 체강 온도는 무려 영하 18도까지 떨어져 아주 추웠습니다 미국 저녁을 강타한 최악의 한파 영상으로 만나보시죠 네 마치 재난 영화의 한 장면 같은 모습이 미국의 현실이 됐습니다 거제 눈폭풍에 제대로 걷기조차 힘든 상황인데요 어머나이 집은 온통 새하얀 고드름으로 뒤덮였습니다 다 고드름에 폭이 내리면서 도로 곳이 마비가 됐습니다 천지네요 네 각조 정부는 비상 사트를 선포하고 나섰는데요 자 이곳은 눈폭탄에 파묻힌 버펄로의 프로 미식 축구 경기장입니다 경기가 연기되면서 어른들의 놀이터로 깜짝 변신하기도 했죠 또이 와중에 재밌어 보이는 있고요네 공주의 뜨거운 물을 뿌리면 얼어붙는 모습 시베리아 아니죠 북미에서도 이제 가능해졌습니다 계란입니다 깨리 자 얼어 붙고요 마치 공중 부양하는 거 같죠 젓가락으로 뜬 라면 면발이 그대로 얼기도 했습니다 SNS 한파의 위력을 보여주는 영상들이 속속 올라오면서 눈길를 끌고 있습니다 얼어붙은 장면들은 꼭 애니메이션 겨울 왕국에 엘사가 왔다 갔나 싶었는데 아 그런데 추위는 동화가 아니지 체감 기온이 영화 51도 있다고 하니까 피해가 컸겠네요네 피해가 상당했습니다 제 이번 폭살 강풍에 항공기가 무덕이 결항이 되는가 하면 인명 피해까지 발생을 했는데요이 빙판길 교통사고와 함께 저체온증으로 미국 저역에 쉰 아홉 명이나 숨지는 상황이 발생을 했습니다 특히 이런 추위를 겪어보지 못한 미국 남부 측에선 더 비상이라고 합니다 매장마다 5년 상품 온열 제품이 나는가 하면 일부 지역에는 생필품 사재기 현상까지 발생했다고 합니다 그야말로 난리군요 아 심지어 이번이 북극 한파가 미국 선거에 영향을 미쳤다라는 분석도 있더라고요네 맞습니다 지난 1월 15일 열린 아이오아 코커스에서 트럼프 전 대통령이 무려 51% 득표율로 압도적인 승리를이 거뒀는데요 투표날 이제 아이오와주의 체감 기온이 무려 영화 40도까지 내려가서 24 년만에 가장 저조한 투표 참여율로 보였다고 합니다 이런 상황에서는 그런 극한 추위를 뚫고라도 투표장에 나와줄 그런 강성 지지층이 얼마나 있느냐가 중요한 문제지 않겠습니까 그렇다 보니까 이제 강력한 팬덤이 있는 그런 트럼프 후보가 유리했던 것으로 그렇게 읽혀집니다 날씨가 도왔던 걸까요 일찌감치 2 3위들을 따 돌렸었는데 이례적인 미국 한파인데이 원인이 뭘까요 역시 기후위 일까요네 아직까지 그 명확한 그 이유는 밝혀지지 않았지만 일부 학자들의 말에 따르면 말씀하신 것처럼 기후 위기가 원인이 아닐까 이렇게 예측을 할 수 있을 것 같습니다 자 화면 한번 보시도록 하겠습니다 자 보시면 원래이 제트기류가 빠르게 회전하면서 북극의 찬공기를 가둬두는 에어 커튼 역할을 하게 되는데요 이처럼 지구 온나나 때문에 제트기류가 약화되면서 이게 아래로 내려온다는 거죠 물론 지구 온난화가 진행이 되면서 이 보통 겨울철보다 좀 따뜻한 날씨를 보이고 있긴 하지만 이렇게 제트 기류가 아래로 내려올 때는 몹이 추워지고 또 때때로 따뜻해지면서이 기후 변화의 폭이 더욱 더 커지고 있습니다 이게 반복되고 있는 현실입니다 아 그렇군요 알겠습니다 첫 번째 픽 이렇게 살펴봤습니다 강하랑 캐스트 이제 자리해 주시고요 계속해서 두 번째 픽도 만나 볼게요이 소식은 이재환 기자님이 준비하셨죠네 저도 강하 강하한 캐스터에게 질 수 없어서 특별히 소품을 준비했습니다 저 오늘이 분위기는 뭔가 많이 신경이 었어요 바로이 모자 때문에 영국이 시끄럽다고 하는데요 키워드 보시죠 아니 모자는 근위병들이 쓰는 모자 아닙니까 맞습니다 흑곰 모자입니다 아 이걸 흑곰 만든다는 걸까요 그렇습니다 추측하는 내용이 맞을지 영상으로 확인하시죠네 아유 모자도 준비하시고 영국하면 떠오르는 상징이죠 빨간 제복의 독특한 검은 털모자를 쓴 왕실 근병 그런데 병의 검은 털모자가 논란에 휩싸였습니다 무슨 일이죠 최근 한 국제 동물 보호 단체가이 털모자를 만들기 위해서 캐나다 흑곰이 희생되고 있다고 폭로하면서 사냥 장면을 올린 건데요네 모자 한개를 만들기 위해서 캐나다 흑곰 한 마리가 희생된다는게 알려지면서 비난이 쇄도하고 있습니다 하나당 사실 근위병의 모자 놀라는 어제 오늘 일은 아닙니다 아 그동안 흑 모피를 쓰지 말자는 시위와 페인이 계속 있었는데요 동물 단체에서는 근병 모자의 진짜 모피를 꼭 써야 할 이유가 없다면서 대신 인조모를 사용할 것을 촉구하고 있습니다 실제로 외관상 봤을 때 모습도 비슷하고요 기능에 있어서도 큰 차이가 없다는 주장입니다 그  그렇습니다 네 하지만 국방부는 왕실로부터 별다른 시정 조치를 받지 못했다면서 모자의 곰 모피를 계속 사용하고 있는 거죠 그렇군요 영국 근위병 모자를 왜 버킹검 군처 같이 대보면 볼 수 있잖아요 그런데 실제 흑권 모피로 만드는 주는 미쳐 몰랐습니다네 동물 보호 단체 페타 공개한 자료에 따르면요 영국 국방부가 2020년에만 10개의 흑군 모자를 구매했다고 하는데요 문제는 모자에 사용될 곰들이 잔인한 방식으로 사냥고 있는 겁니다 총에 맞아서 바로 죽으면 그나마 다행이라고 할 정도로 더체 걸려서 며칠씩 고통받기도 하고요 사냥당하는 곰 일곱 마리 가운데 한 마리는 총에 맞고 부상을 당한 채로 도망치다가 서서히 죽어 간다고 해요 아 게다가 어미 곰미 죽으면 젖을 먹어야 할 새끼 곰들 죽게 되는 경우가 많다고 합니다 아니 생명을 잔인하게 죽여 까지이 모자를 꼭 써야 하나 싶습니다네 영구 왕실 근위병의 정말 상징이라고 할 수 있는이 검은털 모자는 1815년 워터로 전투 이후에 도입이 됐는데요 이제 당시에는 아무래도 전투 중인 그 군인들을 아주 크고 더 위협적으로 보이게 하기 위해서 사용이 됐었다고 합니다 현대에는이 모자가 어떤 군사적인 목적으로 사용되고 있는 것은 아니고요이 전통이 이어져서 어 영국 왕실의 근병 복장으로 남아 있는 것이죠 기역에 남는 그 뉴스 보도가 하나 있었는데 그 작년에 6월 달이었어요 찰스 3세 구강의 그 생일 행사가 있었잖아요 그때 그 리어설 도중에 근위병들이 폭염 때문에 푹푹 쓰러지는 거 그거 기억나시죠 어 맞아요 저렇게 갑자기 쓰러져서네 무게가 정말 꽤 무거워 보이고요 한 여름에 저 털 모자라니 얼마나 더웠을까는 좀 걱정이 되는데 한 여론 주사에 따르면 연구인의 73% 왕실 근위병의 털 모자를 인조 목피로 바꾸자 알았는데 동음 합니다 아 그렇다면 국민적 공감대도 형성된 셈인데 인조 모피를 택해도 될 것 같은데 왜 안 하는 겁니까네 영국 국방부는 일단 일단 모피가 공 개체군 관리를 위해서 캐나다 주가 승인한 합법적인 사냥으로 얻어진 거기 때문에 문제가 없다라는 입장입니다 합법이다 그리고 대체할 만한 성능의 인조 모피가 없었다는 건데요 하지만 동물 보호 단체는 이에 반박 중이고요 게다가 지금 모자가 개당 200만 원이 넘 지난 7간 실 근병 모자만 영국인들의 금이 100만 파 약 17억원이 쓰였다고 합니다 이걸 인조 모피로 대체하면 경제적으로도 이득이라는 주장입니다 그러게 말입니다 전통이라는 이름의이 관습의 변화가 일어날 수 있을지 지켜봐야겠습니다
#
# 🔷 영상 요약 전 후
# 극 한파의 영향으로 미국 북부 지역은 체감온도가 영하 51도 아지 아주 크게 떨어졌고 남부 텍사스 지역은 영하로 잘 떨어지지 않으며 특히 트럼프 대통령은 당선이 확실시 되는 1월 15일에 투표율이 무려 40%를 넘을 것으로 예상된다.
#
# --------------------------------------------------
# Sample 6714
#
# 🔶 영상 요약 전
# 안녕하세요 허팝입니다 지금 우리는 비행기 타고
# 일본 도쿄에 와있는데요 도쿄에서도 바로 아키하바라역 앞에 와있습니다 이곳에 온 이유는 포켓몬 GO 체육관을
# 점령하기 위해서 왔는데요 허팝의 포켓몬 GO 레벨은 현재 35입니다 그래서 구글에서 검색을 해보았습니다 일본 도쿄에서 포켓몬 GO 체육관이
# 어디에 가면 많을까요? 검색을 해보니까 아키하바라역 근처에
# 포켓몬 GO 체육관이 엄청 많다고 합니다 그럼 오늘 여기서 포켓몬 GO 점령에
# 도전해 보겠습니다! 참고로 허팝은 포켓몬 GO에서
# 색깔은 노란색 팀입니다 그러면 어디로 가야 될까? 이쪽이야 가보겠습니다 아... 이쪽이다 아키하바라 체육관 전부 노란색으로 만들기 일단 주변에 체육관이
# 얼마나 많은지 확인해 보겠습니다 체육관 체육관 x2 체육관 x3 체육관 x4 체육관 x5 체육관 x6 체육관 x7 체육관 x8 체육관 x9 체육관 x10 주변에 체육관이 10개 정도 있네요 잠시만 여기는 벌써 허팝 편인 노란색이
# 체육관을 다 점령해놓았습니다 그래서 우리는 여기 빨간색 체육관
# 여기를 점령하러 가보겠습니다! (여기서 잠깐!) 그리고 허팝의 포켓몬들을 소개해 드리겠습니다 여기 보면 허팝의 포켓몬 중에
# 가장 강력한 포켓몬은? 망나뇽입니다! 그리고 메타그로스도 있고요 자포코일도 있고 아주 많은 포켓몬들이 있어요 현재 포켓몬은 1063마리를 가지고 있습니다 일단 여기서 아이템을 조금 얻고요 계속해서 걸어가 봅시다 여기 사람 진짜 많아요 사람 많다... 어쨌든 점점 빨간색 체육관이 다가오고 있습니다 이제 곧 승부를 펼쳐보겠습니다 여기다! 여기가 바로 포켓몬 GO 체육관이 있는 곳이에요 이 건물이 포켓몬 GO 체육관으로
# 정해져있는 건물입니다 그럼 지금부터 빨간색 체육관을 점령해 보겠습니다 승부다! 아키하바라 체육관 점령하기
# 첫 번째 공격 여기서는 지금 포켓몬이 6마리가 있고요 그러면 허팝도 포켓몬을 6마리 지정해 볼게요 망나뇽, 메타그로스 그리고 나머지는 추천해 주는
# 포켓몬으로 시작해 보겠습니다 배틀 시작! 간다 간다 필살기 한 번 사용하고요 이게 포켓몬마다 서로 상성이 있습니다! 그래서 지금 승부에서
# 베스트 포켓몬은 아닌 것 같긴 해요 어쨌든 이겼습니다! 그리고 이제 다음 승부 계속해서 이어집니다 역시 망나뇽이 아주 강력합니다 이제 두 번째 상대방 포켓몬까지 잡았고요! 세 번째 포켓몬 럭키 되겠습니다 이 포켓몬까지 잡을 수 있을지 모르겠는데 한 번 펼쳐보겠습니다 좋아 좋아 상대방 CP가 아주 낮기 때문에
# 우리가 이길 수 있을 것 같아요 자 좋아 지금 망나뇽 혼자서 체육관에 있는 포켓몬
# 다 잡을 수 있겠는데 이어서 갑니다 이번 포켓몬 좀 강력합니다 이야~ CP가 3663! 갑시다! 다 따라잡았다! 자 조금만 더 힘을 내 이겼다 이겼다! 잠시만 이거 망나뇽이 혼자서 다 이길 수 있겠는데? 상대방도 망나뇽이야 CP는 허팝이 더 높은데 졌다... 이어서 갑니다 바로 필살기 충전돼서 바로 필살기 쓰고요 이겼다! 조금만 더! 이겼다! 이제 메타그로스 필살기가 지금 충전돼있기 때문에
# 바로 필살기 쓰고요 또 필살기 쓰고요 이거는 무리다 졌다 우리도 메타그로스 나왔습니다 메타그로스 대 메타그로스 CP는 상대방이 조금 더 높지만 체력은 지금 우리가 더 많거든요 역전당했어 다시 역전했고요 제발... 우리가 우리가...! 아 졌다... 아직 끝이 아닙니다 이번에는 푸크린 나왔고요 푸크린 필살기 빨리빨리 충전되니까
# 필살기 연달아서 공격하고 (하지만 강력한 메타그로스) 이겼다 이겼다! 상대방 체육관에 있는
# 6마리의 포켓몬을 전부 이겼지만 이 친구들의 체력이 아직 남아있습니다 이러면은 이 친구들을 계속해서 승부해서
# 체력을 0까지 전부 다 만드는 수밖에 없어요 여기 계속해서 승부를 펼쳐보겠습니다 아키하바라 체육관 점령하기
# 두 번째 공격 조금만 더! 우리도 필살기 쓰고요 이겼다! 다음으로 우리는 메타그로스 이겼습니다 등장하자마자 상대방을 잡았고요 한카리아스 지금 서로 필살기 썼는데 우리 체력이 거의 바닥났거든요 빨리 또 필살기 써야 돼 제발 이겼다 이겼다! 계속 가봅시다 졌다... 상대방 너무 강력한데? 약간 접전인데 우리가 조금 밀리고 있어 안돼! 조금만 더 힘을 내라고! 상대방이 우리 필살기 맞았는데
# 별로 체력 감소가 없었어 비록 경기는 졌지만
# 체육관 포켓몬들의 체력은 많이 깎았습니다 (두 번째 경기 패배) 그럼 빨리 우리 포켓몬들
# 다시 체력을 다 회복시키고요 포켓몬들 전부 다 체력 충전 됐다 잠시만! 포켓몬이 거의 없어졌는데? (잠깐 사이 점령당한 빨간색 체육관) 이제 상대방 2마리 밖에 안 남았으니까
# 금방 체육관 점령할 수 있을 것 같거든요 우리 망나뇽 CP가 3558, 상대방은 3931 상대방 필살기에 우리 망나뇽이
# 아웃돼버렸습니다! 계속 갑니다 우리 메타그로스 나왔고요 이겼습니다 필살기 쓰고요 이겼다 이겼다 근데 이게 한 경기 이긴다고... 어 뭐지? 끝이 아니네요 한카리아스도 있습니다! 상대방 체력이 많이 안 사라졌어 과연 어떻게 될까? 상대방이 전기 공격에 거의 반응을 안 합니다 그리고 이번에 레어코일이 나왔는데 큰일 났어 포켓몬을 바꿀까요? 이제 우리의 디아루가 나왔는데 디아루가 아주 강력하거든요 이길 수 있을 것 같아요 디아루가 완전 다크호스입니다 잡았다! 이겼다! 오 잠시만 망나뇽 CP가 충전이 다 돼있어 뭐야 이게 포켓몬 또 생겼어 지금 여기에 포켓몬 GO 블루팀 사람들이
# 실시간으로 체육관에게 도움을 주고 있습니다 어딨어? 블루팀 어딨어? 블루팀 나와 빨리 붙자! (다음 경기 ㄱㄱ) 지금까지 승부를 계속 펼치면서 보니까
# 이 친구들이 디아루가한테 약한 거 같아요 그래서 허팝에게 디아루가가 몇 마리 있거든요 디아루가 x5 디아루가 5마리 진출해 보겠습니다 필살기 먼저 써야될 것 같아요 오! 제대로 먹혔다 자 포켓몬... 이겼습니다 또 필살기 쓰면 이길 수 있을 것 같은데 이겼다 기본 공격은 약하지만... 빨리 필살기 충전해서... 그래도 상대방을 잡았습니다 잠시만... 이 친구들 CP를 다 낮췄는데 지금 뭐야...! 또 새로운 포켓몬이 추가됐어 허팝 혼자로는 도저히 점령이 불가능할 거 같은데... (여기서 끝이 아닙니다) 누가 이기나 해보자 살리고요 체력 충전하고요 디아루가 나왔고요 이겼다! 조금만 더 이길 수 있다! 오 이겼다! 이겼다 이겼다 x2 이겼다 x3 이겼습니다! 자 봅시다 상대방 CP 많이 낮췄고요 좋아 좋아 빨리빨리 계속 가보겠습니다 필살기 쓰고... 이겼다! 계속해서 상대방을 잡아가 보겠습니다 잡았다! 기본 공격으로 무찔렀어 이 체육관 이제 전부 다 하트가 낮춰졌어 빨리 허팝의 노란색 체육관으로
# 만들 수 있느냐 없느냐? 우리의 망나뇽이 기본 공격으로
# 체육관에 있는 망나뇽을 이겼고요 상대방 굿바이 필살기 충전 완료 필살기 간다! 그렇지~ 망나뇽 짱 👍 이 친구는 기본 공격으로 아웃! 조금만 더! 상대방 포켓몬 아웃! 이제 상대방 포켓몬 얼마 안 남았다 한카리아스 아웃! 고래왕자 굿바이 이제는 망나뇽 혼자서
# 상대방을 전부 다 잡을 수 있습니다 또 잡았습니다! 아키하바라 체육관 점령하기
# 마지막 공격 이제 포켓몬 한 마리 남았다 파란색 체육관에 포켓몬 한 마리 남았습니다 이제 고지가 눈앞이다! 파란색 체육관을
# 허팝의 노란색 체육관으로 바꿀 수 있어! 간다 간다 고지가 눈앞이다 빨리빨리 기본 공격으로 체육관에 있는
# 우락고래 포켓몬을 잡아내고요! 체력 아웃되었습니다 과연 허팝의 체육관 점령의 결과는? 체육관을 격파했다! 드디어 이겼습니다! 이 체육관은 이제 허팝 겁니다 그럼 여기 체육관에 망나뇽을 놓아놓겠습니다 도쿄에 허팝의 노란색 체육관이 한 개 생겼어! 그러면 우리의 망나뇽에게 간식을 주겠습니다! 간식을 주면은 체육관에 있는
# 포켓몬 체력이 충전이 되고 허팝도 별의 모래라는 아이템을
# 획득하게 됩니다! (체육관 점령 성공) 그리고 지금 여기 보면... 메가 리자몽X 이거를 잡고 있는데 여기에 제가 동참해서 같이 한번 잡아보겠습니다 레벨이 33, 33, 36, 42, 35, 41 전부 다 레벨이 엄청 높네요 경기 시작합니다 엄청 강해보이는데 필살 공격 연달아서 필살 공격 그리고 또 필살 공격 또 필살 공격 좋아 조금만 더 힘을 내 필살기 가자 가자 필살기 잡았다! 그러면 다시 보겠습니다... 잠시만! (빨간색 체육관에 점령당한 허팝 체육관) 여기 허팝이 좀 전에 노란색으로
# 체육관 점령했었는데 그 사이에 체육관을 빨간색 팀에게 뺏겼습니다 이 체육관은 항상 노란색이어야만 합니다 우리 포켓몬들 체력을 충전시켜줄까요? 이제 회복약이 없어! 더 이상 포켓몬 체력을 회복을 시킬 수가 없습니다 이제 더 이상 경기를 할 수가 없어요 그 많던 회복약을 다 써버렸습니다! (오늘 포켓몬 GO는 여기까지!) 여러분들 오늘 도쿄에 포켓몬 GO 체육관을
# 전부 다 점령하러 왔는데 생각보다 아주 강력한 포켓몬 GO 플레이어들이
# 너무 많았던 거 같습니다 여기 이 건물에 있는 포켓몬 체육관 하나를
# 몇 분 동안 점령을 성공을 했었긴 했지만 몇 분 후에 바로 다시 뺏겨버렸습니다 그리고 이제 더 이상 회복약이 없기 때문에
# 포켓몬 GO 진행이 어려운 상태입니다 일단은 이대로 한국에 다시 돌아가야 될 것 같습니다 다음에는 포켓몬 GO 레벨 50
# 만렙인 친구들을 모아서 팀을 꾸려가지고 이곳 일본에
# 포켓몬 GO 체육관 점령하러 다시 오겠습니다 그때는 화면에 나와있는 모든 체육관을
# 노란색 체육관으로 모두 점령해 보겠습니다 TO BE CONTINUED! 허팝이 포켓몬 GO는 다시 찾아온다
#
# 🔷 영상 요약 전 후
# 허팝은 포켓몬 GO 체육관을 5개나 점령해놓았는데요 빨간색 체육관을 점령하러 가보겠습니다
#
# --------------------------------------------------
# Sample 1027
#
# 🔶 영상 요약 전
# ...
#
# 🔷 영상 요약 전 후
#  5oral  5 we  wer  선생님께서 친구들 등자 때리면서 한 명씩 가 뜨리고 다니지도 받아내고 다니지도 받아내고 하는 20 체계를 특히 질렀어 좋아요  선생님께서 친구들 등자 때리면서 한 명씩 가 뜨리고 다니지도 받아내고 다니지도 받아내고 하는 20 체계를 특히 질렀어 좋아요  선생님께서 친구들 등자 때리면서 한 명씩 가 뜨리고 다니지도 받아내야 아예 그때 20 체계를 특히 질렀어 좋아요                                                                                                                                                                                1경기 가 중학교 2학년 때 제가 많이 괴롭혀 없거든요 정말 엎드려 있으면 동작도 많이 때리고 됐는데 왜 제가 기억에 나왔을까요 음 11년 전 제 자산 여기가 제가 근무하고 있는 3 정정 학교를 찾아서 보고 있다고 합니다 생각지도 못했던 일이라 사실 어젯밤 많이 흘렀어요 어색할 것 같아요 퍼스 산 여기가 정말 말을 잘하지 않는 친구 였거든요 제가 굉장히 때문에  3 여기는 노 재미죠 되게 순하고 마음 여리고 제가 이제 화를 내며 깜짝 놀라고 실험적 밖에 없네요 저희 주제와 없었죠 태그 자 이제 선생님께서 친구들 등자 때리면서 한 명씩 가 뜨리고 다니지도 받아내야 아예 그때 20 체계를 특히 질렀어 좋아 근데 사실 한 번 시간은 잘 안 들었어 집을 내 대사 외에 화면 구성 중에 전해졌고 요통 각각 으 이제 좀 그양 시더 외우는 걸 안 좋아요 얻어 잡지 에 그렇지 그래서 맞았지 어 트 얘기를 내가 제자들은 대 쩡이 자기도 상영이 더 큰 인물이 될 거라고 때려달라고 예 그래서 1 부러뜨려 달라고 와 이들이 위해서는 마주 줘 어 그래서 사역이 참 클
#
# --------------------------------------------------
# Sample 33
#
# 🔶 영상 요약 전
# 호주의 고양이 대전쟁의 이야기를 한번 해보도록 하겠습니다 호주 얘기입니다, 호주 오스트레일리아, 그쵸? 자 호주가 동물들하고 전쟁을 펼친다는 얘기는 어제 오늘 얘기가 아닙니다 우리 슈카월드에도 많이 등장했던 호주의 동물 대전쟁 일단 첫 번째 1차 애니멀 월 에뮤였죠? 기억이 나실 겁니다 우리 에뮤가 호주에서 대전쟁을 펼쳤는데 그때 보신 분 아시겠지만 여기 한번 링크 나갈 거예요 다시 가서 보시면 알겠지만 그 에뮤의 대장 에뮤 우리 엠퍼러 에뮤가 등장하면서 호주 군인들이 여기 왔지만 대패했죠 에뮤도 조직력이 상승할 수 있구나 에뮤도 조직력이 있다는 걸 보여주면서 참전했던 호주가 대패한 사건이 있었는데요 그리고 2차적으로 에뮤에선 졌지만 토끼에선 이겨보겠다 그래서 제2차 토끼 워가 펼쳐졌습니다 실제입니다 웃기려고 얘기하는 게 아니라 실제로 펼쳐졌어요 호주에서 토끼를 막아보겠다 사냥, 울타리, 천적 심지어 세균전까지 아 이런 거 하면 안되는데 케미컬 월까지 하고 바이올로지컬 어떤 무기 웨펀까지 투입했지만 졌죠 그냥 패배했고 울타리까지 쳤지만 안됐구요 물량 러쉬에 그냥 저글링 러쉬죠 물량 러쉬에 그냥 싸우러 온 저그에 그냥 패배했고 지금도 활기를 치고 있는게 토끼라고 할 수 있구요 토끼 전쟁 당시에 휴먼들이 어떻게 해보려고 용병으로 여우를 영입했었죠 여우를 영입해서 우리 편인 줄 알고 토끼하고의 전쟁에 투입했는데 이 자식이 배신을 때리면서 토끼를 잡아먹지 않고 괜히 옆에 있는 토끼는 빠르잖아 또 여우가 위험한 걸 알아 굴로 잘 숨어 만만돌이, 유대류 이런 귀한 애들 얘네들을 보호하려고 데려왔더니 이거 호주대륙에 밖에 안 사는 희귀하게 그지없는 이런 애들 잡아먹다가 지금은 토벌의 대상입니다 물론 토벌은 안 됐어요 역시 패배를 했죠 지금까지 인류가 호주에서 그나마 좀 성과가 났다 싶은 거는 캐멀 어떤 분들은 타조라고 부르던데 캐멀 우리 캐멀 형들은 헬기에 무력했습니다 헬기에 집단으로 다녔어 집단으로 아하 헬기에 무력한 모습을 보이면서 개체 조절의 대상이 되고 있습니다 우리 중에 최약체였어요 이 몸은 조금 그래도 어떻게 좀 우리가 인간이 휴먼이 빅토리를 가져올 수 있었죠 지금까지 쭉 이렇게 애니멀 대 인간의 호주에서 대전쟁을 봤는데 그런데 오늘의 주제이면서 이 모든 녀석들 중에서 사실상 최강 보스가 있습니다 에뮤, 토끼, 여우 이런 거하고는 비교가 안 되는 최강 보스 바로 킹냥입니다 비교가 안 돼요 거의 뭐 갓입니다 갓, 볼드모트, 사우론 뭐 이 정도인데 킹냥이는 당하기가 힘들어요 이미 2015년에 호주는 야생 고양이와의 전쟁을 선포했습니다 2020년까지 200만 마리의 야생 고양이를 잡아 개체수를 조절하겠다 왜냐? 호주 환경부 장관이 이렇게 얘기를 했습니다 야생 고양이가 매년 약 20억 마리의 동물을 죽이고 있다 게다가 호주는 고립되어 있는 대륙이기 때문에 호주만의 고유종이 진짜 많죠 근데 이 호주만의 고유종들이 야생 고양이 같은 침입종으로 그대로 절멸을 당하고 있기 때문에 호주의 생명 다양성 손실의 가장 큰 원인이다 그리고 고양이는 원래 호주에 없었던 겁니까? 침입종입니까? 침입종이요 외래종이요 그럼 호주가 바다인데 어떻게 들어왔냐 휴먼 휴먼들이 특히 유럽인들이 호주에 들어오면서 애완동물로 고양이를 데리고 왔는데 18세기 후반에 이 깃발 휘날리는 영국이 뭐 하면 다 영국인데 호주에 고양이를 데리고 옵니다 그리고 고양이를 처음 본 호주의 토착 생물들은 거의 속수무책 고양이가 귀여워 보이지만 생태계 거의 최종 포식자에 가깝죠 고양이를 잡아먹는 포식자들은 위에 물론 대형 포식 동물들이 있지만 대형 포식은 잘 없잖아요 거의 최종 포식자인데 호주의 소형 동물들은 완전 속수무책 34개의 토착종이 멸종을 했고요 200종 이상의 종이 멸종 위기에 몰려있죠 게다가 귀엽게 보이지만 고양이들의 살상 능력은 어마어마하다고 합니다 야생고양이 한 마리가 하루에 두 마리 꼴로 생물을 죽인다 1년에 한 마리가 700마리를 죽일 수 있다 호주에서만 하루에 야생고양이가 한 250만 마리 300만 마리  예상합니다 하루에 600만 마리의 생물이 고양이한테 죽는단 말이다 1년이면 20억 마리의 파충류 새, 작은 포유류, 유대류 이런 애들이 고양이에 죽고 있기 때문에 아까도 말씀드렸지만 호주가 희귀 동식물들의 낙원으로 불리죠 대단히 희귀한 호주에만 있는 이런 조그만 소형 유대류들 우리는 잘 모르는 빌비, 코알라, 캥거루 이렇게 큰 애들만 아는데 작은 애들도 많이 있어요 빌비, 베통, 넘밧 뭐 이렇게 얘기하는데 다 멸종위기 중입니다 극심한 개체수 감소 고양이의 상대가 안 되죠 피해 도망도 못 가고 상대가 안 되기 때문에 걸리면 죽는 그런 입장이라고 할 수 있고 18세기 후반에 유럽인들이 데려온 고양이가 지금 야생고양이가 호주 전역에 얼마나 퍼져 있냐 사실상 99.9 % 고양이가 없는 지역이 없다 고양이는 생존 능력도 대단합니다 더워도 심지어 사막에서도 버틸 수 있기 때문에 280만 마리 정도가 넓게 퍼져있구요 물론 많이 모여 사는 데는 있죠 호주 정부가 고양이 개체수를 그럼 좀 조절해 보자 멸종할 수는 없으니까 토착 생물들이 호주가 그동안 많은 야생동물과의 싸움에서 대부분 대패를 했던 이유는 하.. 이게.. 만만해 77배야 이게 뭐 사막이고 뭐.. 이걸 어떻게 잡을 거냐 아까 전에 낙타 같은 애들이야 헬기 타면서 잡았는데 이거는 불가능한 애들이죠 게다가 최상위 포식자 숲, 산림지대, 초원, 늪지, 건조지대 심지어 도심에서도 삽니다 옛날에는 그나마 호주 원주민들이 많았을 때는 원주민들이 얘네를 식용으로도 잡아먹었대 1890년대 아주 옛날에 왜냐하면 토착종이 줄어드니까 원래 걔들을 잡아먹고 살다가 야생 고양이들이라도 잡아먹었는데 휴먼이라도 어떻게 해봤는데 지금은 그런 소리 하면은 몰매 맞죠 그런 소리 하면은 한국인들 개고기 먹냐 라는 소리하고 똑같기 때문에 원주민이 옛날에 고양이를 포식했다는 전설 같은 얘기가 있는 거지 요즘 원주민들한테 이런 소리 하면은 돌맞을 일이지 무슨 말도 안 되는 1800년대 조선시대 얘기하고 있는 거라고 생각을 하죠 그거랑 똑같이 고양이 잡아먹는 뭐 이런 건 다 없어졌고요 그러다 보니까 호주 야생 고양이를 잡을 수 있는 천적도 없고 그래서 호주가 야생 고양이를 국가적 외래종으로 선포합니다 호주 역사상 가장 파괴적인 침입 외래종이다 이거는 뭐 어떻게 할 수가 없다 그래서 호주 환경부 장관이 이렇게 표현을 했습니다 야생 들고양이는 몰래 따라와 습격하는 무자비한 살인자들에 가깝다 우리가 지금 행동하지 않으면 토착 동물들은 살아남을 기회가 없다고 선언을 한 거죠 그래서 2015년에 200만 마리의 야생 고양이들을 줄여야 된다 야생고양이 숫자를 280만, 300만 정도 보니까 3분의 2 정도의 고양이 숫자를 줄여야 된다 어떻게든 사살을 하건 약을 통하건 어떻게든 줄여야 된다 그리고 환경보호론자들도 이때 일부이긴 하지만 호주 생태계를 과거로 되돌릴 수 있다는 거니까 나름 지지를 했습니다 다만 어떻게가 문제죠 어떻게 형을 어떻게 잡냐 이 헬기를 타고 낙타 숫자를 조절했잖아요 기관총을 쏴가면서 낙타 숫자를 조절했는데 낙타 전쟁에서 승리한 것처럼 헬기를 타면서 이 고양이를 잡을 수 있냐 자동차로는 불가능하고 남한의 70배라는데 불가능하고 될 리가 없죠 낙타들이야 무리생활을 하고 저렇게 멍청하게 큰 놈들이 몰려다니니까 그렇지만 고양이는 야행성이야 어디에 숨어있어 야 헬기 타고 다니면서 그거 언제 잡어 200만 마리, 200만 마리 게다가 굴을 파고 굴 안에 있어요 이게 될 리가 없고 그럼 한 마리씩 차를 타고 다니면서 총으로 물론 잡을 수 있죠 아까도 얘기 드렸듯이 목표가 200만 마리입니다 고양이는 생후 5개월부터 새끼를 낳는데 여러 마리 낳죠 그러면 잡는 게 빠르냐 태어나는 게 빠르냐 그리고 이거 호주 전역 대륙에 99% 퍼져 있다는데 이거 언제 답이 없죠 그래서 호주 정부도 휴먼도 아이디어를 냅니다 독극물이 담긴 소세지를 무한 투하하겠다 하하하 어.. 근데 이것도 쉽지 않아요 왜냐하면 첫 번째 이건 고양이만 죽는 게 아니죠 다른 생물들도 죽을 수 있어요 두 번째, 고양이가 너무 넓게 퍼져 있어요 호주 대륙의 99%입니다 타겟팅하기도 어렵고 너무 넓게 퍼져 있고 ...
#
# 🔷 영상 요약 전 후
# 호주에서레일리아에서 동물들하고 전쟁을 펼친다는 얘기는 어제 오늘 얘기가 아니며 우리 에뮤가 호주에서 대전쟁을 펼쳤는데 그때 보신 분 아시겠지만 여기 한번 링크 나갈 거예요
#
# --------------------------------------------------
# Sample 7545
#
# 🔶 영상 요약 전
#  오오오  이번달 일본에서 발매된 주술에 전 20권 에는 후식으로 토지의 일상이 실려 있습니다 짧은 부록 이지만 이번에 공개된 내용을 통해 몇 가지 의문점이 해소된 부분이 있어서 영상으로 만들어 보았습니다 주술에 전편 북에는 주요 캐릭터의 나이가 기재되어 있고 이것은 2018 년 10월 31일 시부야 사가 시점에 나이입니다 먼저 시부야 사변 당시 고조에 나이는 28살 메구미는 15살 일본은 만나 이를 사용하기 때문에 12월생 인 두 사람은 생일이 지나지 않아서 아직 한 살을 먹지 않았지만 2018년 은 각각 29 16이 되는 해입니다 그리고 2018년 으로부터 12년전 성장 체 아마 나의 리코의 사례 사건이 일어났습니다 시부야 사변이 끝난 후 2 쿠모 육지와 함께 텡게 늘 만나러 갔을 때 즉 금오도 탱 겐도 성장 체사레 사건을 11년전 이라고 말해 팬들을 어리둥절하게 만들었는데 이것은 후에 단행 분이 나오며 12년 전으로 수정이 되었으므로 이 사건은 2006년에 일입니다 장식 오존은 주수 고전 2학년 나이는 16살 때 고민은 세 살입니다 1녀 도 2007년 08월 4 토르는 최강희 되었다 개 토스 그루가 주저 설 없어 처형 대상이 된 2007년 고조에 나이는 17살 메구미는 네 살입니다 초등학교 1학년 때 내 부친과 춤이 키에 모친 각자 한쪽 부모가 눈이 맞아 증 발했다 외국 이가 초등학교에 입학한 것은 2009년 4월 이때 고조는 19살 메구미는 여섯 살입니다 주술에 전 7권 에서 매 구미에 회상이 나왔을 당시에는 과거 편의 시작하기 전 이었기 때문에 아무런 위화감이 없었지만 바로 이어서 시작된 과거 편에서 토지가 사망했습니다 그리고 사망한 지 3년이 되었는데 외 구미는 마치 얼마 전 두 사람이 증발한 것처럼 얘기 했기 때문에 이 부분이 다시 그 화제가 되며 그가 아빠 라고 생각하는 인물이 토지가 아닌 다른 사람일 가능성 과 사실은 고조 와의 전투에서 토지가 죽지 않았다는 추측이 나오기 시작했습니다 그리고 개개 선생은 이 것을 의식한 듯 9건 에서는 몇 년이나 만나지 않아서 얼굴이 기억나지 않는다 는 대사를 넣어 토지가 죽었다 는 점을 명확히 있습니다 즉 몇 년동안 만나지 않은 토지 며칠 전부터 사라진 츠미키 에 엄마 이젠 인가와 의 거래로 큰 돈을 받았을 거라는 추추 이것들이 합쳐져 토지와 주 미키 엄마가 함께 증발해 어딘가에서 잘 살고 있을 거라는 결론에 이른 것입니다 한편 0 시우가 토지 에게 외국 위해 안부를 묻자 토지는 매 구미 라는 사람 자체를 기억하지 못했습니다 나중에 자기 아들이 매 구미 라는 것을 깨달았고 사실은 아들에게 애정이 있었다는 것과 내심 젠 인가에 보내고 싶지 않았다는 것이 밝혀졌지만 아들의 존재 자체를 잊은 부분이 너무 커서 쓰레기 아빠 라는 오명을 완전히 벗을 수는 없었습니다 그래서 아들의 이름을 잊을 정도면 대체 얼마 통한 만나지 않았던 것인지 한 집에 살았던 시기 가 있긴 있는 것인지 이런 의문이 남았는데요 이번 주술에 전 20권 에 실린 부록으로 여기에 대한 궁금증이 해소 되었습니다 밖에서 싸우고 돌아온 매 구미를 스 미끼가 혼내는 장면인데 그녀는 싸움은 하는게 아니라 말리는 것이 라는 특이한 말을 합니다 알고보니 이것은 과거의 토지가 한 말로 집에서 tv 를 보고 있는 토지가 등장 누군가와 싸워서 쓰러뜨려 맞자 나중에 교사나 경찰이 시끄럽지 않아 하지만 누군가의 싸움을 말리면 칭찬 받을 수 있고 덤으로 최소한 두 명 때릴 수 있어 다시 말에 말리는 척하면서 2명을 때려 높이면 스트레스 해소와 칭찬 두 마리 토끼를 잡을 수 있다는 토지 다운 명언 인데요 어떤 이치인 지지 미키는 이해할 수 없었지만 어쨌든 이것을 제대로 기억하고 내 구미에 게도 가르치고 있었습니다 gpt 는 매 구미 보다 1살 많기 때문에 토지 사망 당시 네 살에서 5살 정신 연구결과에 따르면 인간은 세 살까지 의 기억은 되게 없는 것으로 알려져 있으며 이것을 유아 기억상실증 이라고 합니다 그리고 내 5사 사이에 기억 횟수가 급격히 증가 에 정차 선명한 기억을 갖게 된다고 하는데요 물론 모든 사람에게 적용되는 것은 아니지만 작중 그녀가 특별히 머리가 좋다거나 하는 묘사는 없으므로 평범했다 는 전제하에 토지의 얼굴 말과 행동을 제대로 기억하고 있는 것을 보면 회상 장면은 4g 가 사망한 2006년 쯤 일어난 일이 아닐까 생각합니다 결론적으로 토지가 한 집에 살았던 시기는 분명히 있고 의외로 메구미와 도 최근까지 만났을 가능성이 높은데 이름을 기억하지 못한 것은 쓰레기 물 강조해서 나중에 반전 효과를 출연한 작가의 계획이었다 는 것이겠죠 또한 자신은 남자 이름을 기억하지 못한다는 말도 하는데 자기 아들을 남자 카테고리에 넣어야 하는 건지는 잘 모르겠습니다 아직 풀리지 않은 수수께끼는 주 미키 모친 인데요 단순히 아이를 버리고 가출한 것인지 뭔가 사고가 있었는지는 밝혀지지 않았고 캔 적극 계획 설이 있긴 하지만 짐이 키가 마킹 되었다는 건 왜 근거는 없습니다 메구미는 아직 아빠가 살아 있는 줄 아는데 대개 선생은 토지에 대한 것은 고조 사토루 의 입으로 매 구미 에게 전해야 한다고 생각하고 있다고 했으므로 옥문 강에서 나온 후 어쨌든 한 번은 고조와 매 구미가 만날 것으로 보입니다 그럼 저는 다음 영상으로 돌아오겠습니다 구독과 알림 설정을 하시면 가장 빠르게 영상을 보실 수 있습니다 시청해주셔서 감사합니다
#
# 🔷 영상 요약 전 후
# 이번달 일본에서 발매된 주술에 전 20권 에는 후식으로 토지의 일상이 실려있는데 전편 북에는 주요 캐릭터의 나이가 기재되어 있고 이것은 2018 년 10월 31일 시부야 사가 시점에 나이인 28살 메구미는 15살, 12월생인 두 사람은 생일이 지나지 않아 아직 한 살을 먹지 않았지만 2018년 은 각각 29 16이 되는 해로 구성되어있다.
#
# --------------------------------------------------
# Sample 2865
#
# 🔶 영상 요약 전
# 생명의 위협을 무릅쓰고 남한에 넘어온 탈북민들은 이 땅에서 '생업'을 해결해야 하는 현실에 놓이게 됩니다. 낯선 장소, 낯선 사람들 사이에서 홀로서기를 시작하는 탈북민에게 '취업'은 가장 큰 '정착' 과정이 될 텐데요. 하지만 정보 부족과 편견이란 벽에 가로막혀 탈북민 스스로가 취업을 하는 건 쉽지 않다고 하죠. 이런 탈북민들의 고용을 지원하고, 취업 기회를 제공하기 위한 캠페인이 있는데요. 이 캠페인을 통해 탈북민들이 취업에 성공한 현장에 김옥영 리포터가 다녀왔습니다. 함께 보시죠. 한국에 정착한 지 7년째, 탈북민 정희 씨가 길을 나섭니다. 오늘 어디 가시는 길인가요? 출근하는 길이에요. (출근요? 어디로 출근하시나요?) 농어민문화체육센터요. 활기차게 나선 출근길. 힘찬 시동 소리와 함께 일터로 출발합니다. 회사로 가는 길에는 늘 경쾌한 음악이 함께한다고 하는데요. 어떤 기분으로 출근하시나요? 출근을 하게 되면 나도 이런 직업이 있고 직장인이라는 것만으로도 출근하는 자체가 좋아요. 차로 20여 분 거리의 직장에 도착했습니다. (도착했네요.) 네, 여기입니다. 이제 가장 중요한 순서가 남았는데요. (이건 뭐 하는 거예요?) 출근 도장 찍는 거예요. (출근 도장, 제일 중요한 거네요.) 지난 4월 이곳에 채용된 정희 씨는 시설 관리와 대관업무를 주로 맡고 있습니다. 탈북민이 남녘에서 성공적으로 정착하는데 직업을 구하는 건 대단히 중요한 요소인데요. 남북하나재단의 1사 1인 캠페인으로 취업에 성공한 정희 씨는 이 직장에서 어떤 꿈을 키워가고 있을까요. 본격적인 업무 개시와 함께, 시설 점검에 나섭니다. 안전과 위생을 중심으로, 곳곳을 꼼꼼하게 살펴봅니다. 창문이 열려있는지 수돗물이 물 흐르게 떨어지고 있는지 수전(수도꼭지)들 체크하고 바닥이랑 아무 이상 없는지 확인하는 겁니다. 사무실로 돌아와서는 대관 일정을 정리하고, 운영 자료를 능숙하게 챙기는데요. 2018년 한국에 도착한 정희 씨는 취업을 위해 만반의 준비를 해 왔다고 합니다. 자격증은 세무회계 2급이랑 FAT(회계정보 활용능력) 1급이랑, ERP(전사적 자원정보 관리사) 1급, ITQ(정보기술자격) 다 있습니다. 덕분에 업무에도 빠르게 적응할 수 있었다고 하는데요. 취업에 대해서 교육도 받고 다 했기 때문에 크게 우려되는 건 없어요. 지금은 직원들하고 잘 어울리고 열심히 하는 모습도 좋고 아주 만족하고 있습니다. 여러 자격증과 빼곡히 필기한 노트에서 그동안의 노력을 짐작해 볼 수 있습니다. 엑셀에는 영어들이 많이 나오더라고요. 제가 영어가 약해서 못 알아듣는 부분이 너무 많았고 처음에는 이렇게 여기 위탁 관리랑 위탁 관리 도구 (용어를) 이해 못했어요. 과거 정희 씨는 생계를 위해 취업 전선에 여러 번 도전했지만 결과는 쓰디쓰기만 했습니다. 면접까지 잘 봤는데 마지막에 가서 고향이 어디냐는 (질문에) 이북이라고 이야기하면 연락도 없고 그렇더라고요. 이제는 안정된 직장에서 조금씩 평범한 꿈을 키워가고 있는데요. 가족들이 건강하고 행복하게 사는 게 바라는 거고요. 지금 회사에 채용되기까지는 조력자의 도움이 컸다고 합니다. 남북하나재단 상담사 선생님입니다. 제 취업에 많은 도움을 주신 분이에요. 오늘 방문은 정희 씨의 회사 생활을 알아보고, 응원과 격려를 전하기 위해서라는데요. 남북하나재단에서 지난해부터 진행 중인 '1사 1인' 캠페인의 하나입니다. 어때요. 업무는 적응 잘하신 거예요? (아직 적응 중이에요.) 상대적으로 낮은 고용률, 높은 실업률을 보이는 탈북민들이 취업을 통해 자립할 수 있도록 돕고 있는 건데요. 남북하나재단에선 취업관리시스템을 구축해 공공기관 등 정규직 일자리를 대상으로 직업 훈련을 마친 탈북민을 연결해 주고 있습니다. (1사 1인 캠페인은) 한 업체에서 북한이탈주민을 한 명씩 채용하자 이런 사회적 분위기를 만들고자 남북하나재단에서 진행하고 있는 캠페인입니다. 오늘도 많은 탈북민들이 구직의 문을 두드리고 있는데요. 무엇보다 1사 1인 캠페인이 확대되기 위해서는 편견과 차별을 지우는 기업과 사회의 노력이 필요한 상황입니다. 서울 서초구의 한 병원. 2019년 한국에 온 영옥 씨가 간호조무사로 근무 중입니다. 안녕하세요. (안녕하세요. 반갑습니다.) 영옥 씨는 5개월 전 1사 1인 캠페인을 통해 이 병원에 취업했는데요. 자신만의 방법으로 주어진 업무를 야무지게 처리해 나가고 있습니다. 검사를 할 때 검사 순서 이렇게 적어 놓은 거 혼자 보고 있는 거예요. (정리해 놓으신 거구나.) 네. 출퇴근길 틈틈이 외운 전문 용어도 이제 제법 익숙해졌다고 하는데요. 낯선 단어를 외울 땐 재치를 발휘하기도 했습니다. (이거는 뭐예요?) 토니캣(채혈 고무줄)이요. 가수 토니 그분 이름이 토니잖아요. (H.O.T. 토니요?) 네, 그런 식으로 외우고 그랬거든요. 북한에서 군인이었던 영옥 씨는 탈북해 중국을 거쳐 한국에 오게 되었는데요. 우리 혈압 한번 재볼게요. 종종 자신의 말투와 억양에 낯설어하는 환자들을 만날 때면 주눅이 들었다고 합니다. (환자가) '말투가 어디 사람이에요' 하고 여쭤볼 때 그때 당황스럽죠. 그런 영옥 씨에게 동료들은 가장 큰 힘이 되는 존재인데요. (환자가) '어디서 왔어요.' 그렇게 여쭤보시거든요. 그러면 '저 강원도인데요.' 그렇게 대답하거든요. 다른 선생님들이 웃으시거나 그런 게 아니고 괜찮다고 괜찮다고 당당하게 얘기하라고 그렇게 말씀해주셔서 그건 진짜 좋은 것 같아요. 틈틈이 소통하며, 남과 북의 경계를 허물어 나가는 일터. 아까 환자 바이탈(건강 상태) 괜찮았어요? (네, 다 좋았습니다.) 직원들이 가졌던 약간의 편견은 함께 일하며 지워 나갔다고 합니다. 탈북민이라는 사실을 아시는 분들도 꽤 많아요. 개인적인 질문도 많을 거고 곤란한 상황도 많을 텐데 잘 이겨내시고 유연하게 대답도 잘 해주시고 오히려 재치 있게 풀어나가시는 편도 있으시고 그러시더라고요. 영옥 씨의 채용 사례가 좋은 선례를 남기며 또 다른 탈북민 채용의 문을 열어가고 있습니다. 직원들이 함께 근무하면서 만족도가 높아지고 이런 분이 계시면 또 채용할 수 있는 의향도 있고 직원들 만족도도 높고 열심히 하시니까... 한 달에 한 번 열리는 직원들의 생일잔치. 이날은 영옥 씨가 주인공입니다. 몸이 아픈 남편, 대학생이 된 아들과 함께 오래오래 행복하게 살고 싶다는 영옥 씨. 너무 행복합니다. 앞으로 잘 부탁드리겠습니다. 감사합니다. (잘해봅시다요.) 탈북민들이 우리 사회의 구성원으로 확실하게 뿌리 내릴수록 우리 안의 통일도 조금씩 앞당겨지고 있습니다.
#
# 🔷 영상 요약 전 후
# 탈북민들의 고용을 지원하고, 취업 기회를 제공하기 위한 캠페인으로 탈북민 정희 씨가 출근하는 길, 안전과 위생을 중심으로 시설 점검에 나선다.
#
# --------------------------------------------------
# Sample 625
#
# 🔶 영상 요약 전
# 네 어제요 오늘도 시장은 약세를 보이면서 어느새 230으로 미끄러졌습니다 그래도 개인들은 매수에 나서고 있다는 점이 그나마 다행인 걸까요 5월을 하루 남겨 주고 6월 장은 어떻게 전략 세워봐야 할지 이마에 산다 임종의 돌파 트리거에서 투자 전략 세워 보겠습니다 안녕하세요 대표님 반갑습니다네 야금야금 오르던 환율에 국채 금리 급등까지 이게 전반이 흔들리니까 어떻게 해야 되지 너무 걱정이 많 맞습니다 어 투심이 상당히 좀 많이 위축되고 있는 면이기 때문에 어 트레이딩 하시는 분들도 어렵고요 지금 그리고 이제 투자의 관점으로 접근하시는 분들도 지금 고전을 면치 못하고 있는 어 상황입니다 그럼에도 불구하고 어 자체 발강 어 주가 상승 촉매제 스토리를 보유하고 있는 기업들 중 어 바닥권에서 에너지를 모으고 있는 기업들은 관심을 가져야 되고 어 그런 유의 기업이 있다면 제가 돌파 트 리그를 통해서 소개해 드리고 있습니다 그래도 바닥권 종목을 보는 공략법을 소개해 주셨습니다 입니다서 그렇다면 첫 번째 주제는 어떤 것들이 있을지 들어가보도록 하겠습니다 한중 정상회담과 한중일 정상회의를 계기로 한중 관계가 개선될 것이라 기대감이 엔터 콘텐츠 주들의 바람을 불어놓고 있습니다 대표님 눈물의 엔터주 이젠 올라갈 수 있을까요 눈물의 엔터주 예 눈물을 너무 많이 흘렸습니다 그래서 더 이상 흘린 눈물도 없어요 매 말랐어요 그래서 너무 많이 속았어요 아 그렇죠 근데 이제는 어느 정도 찐하게 윤곽이 좀 나오고 있고 뭐 SM 블록들 이슈 나오기 전에 한번 시원하게 급등 했잖아요 그런 식의 기술적 반등 드라마를 연출할 수 있는 엔터주가 있다면은 관심을 당연히 가져야 된다고 저는 보고 있습니다 자 한미 FTA 2단계 협상 내의 내용에 문화 개방이 포함되어 있다라는 거 꼭 어 기억을 하셔야 될 것 같습니다 그래서 어 이런 한중관계 개선 이슈로 엔터 주의 투심이 개선될 수 있고요 그리고 참고로 한국 인디밴드의 베이징 공연이 최근에 승인된 어 뉴스도 확인할 수 있었고 어 그리고 이제 2020 2016년 사스사태 이후 어 실시된 한안 해제 기대감이 어느 정도 무루 있게 되다 보면은 이제 엔터 대표주의 어 기술적 반등 흐름이 전개될 수 있다라고 저는 어 보고 있습니다 만약에 한한령이 어 유의미하게 풀릴 경우 음반 판매및 콘서트 수입이 크게 어 증가하게 될 것으로 기대가 되고 있고 특히 중국 현지 공연 재개시 중국 팬덤이 어마무시한 일부 엔터 기업들이 큰 수혜를 볼 수 있고요 어 중국 팬덤이 어 큰 아이돌 그룹으로는 에스파 엑 NCT 등이 있기 때문에 어 만약에 어 중국 한역 해제시 어 가장 크게 수요를 보 수 있는 기업은 단원 콘대 SM이라고 저는 보고 있습니다 어 그럼 오늘 관심주 SM 있가 아닙니다 어 뭐예요 예 SM 이제 오른 거 반납하고 약간 좀 예 좀 길수 위치가 나쁘진 않은데 SM 다 어 훨씬 더 어 낙폭과대 메리트가 부각될 수 있는 기업이에요 그 기업의 이름은 바로 와이즈 한다기보다는 어 내년에 돈을 좀 많이 벌어다 줄 가능성이 높아 보입니다 지금 베이비 몬스터에 대한 글로벌 주목도는 이제 유튜브 구독자 수나 뭐 뮤직비디오 어 조회수 등으로 판단을 내릴 수 있는데 어 글로벌 주목도가 생각보다 높고요이 멀 자는 미래에 잘하면 뉴진스 구독자수를 어 이길 수도 있지 않을까 뭐 지금 당장은 아니지만 그런 판단이 들고 있고요 제가 또 어 걸그룹을 유심히 이제 분석하는 경향이 있는데 어 능력치가 상당히 출중한 그런 걸이라고 저는 보고 있기 때문에 세계 시장에서 통할 것으로 어 기대가 되고 있습니다 그리고 올해 8월 달에 일본 최대 음악 페스티벌에 이제 출연을 이제 베이 몬스터가함으로써 글로벌 어 공략을 본격화할 거고 또 올해 하반기 중으로 미니 앨범은 이미 나왔고 전기 앨범 출시를 통해서 더욱더 이제 글로벌 시장 팀 2에 더욱더 심혈을 기울일 것으로 어 보고 있습니다 그리고 내년 정도 되면은 블랙 핑크 완전체 활동에 대한 윤곽이 나올 거예요 그래서 베이비 몬스터가 내년에 유의미한 성과가 나오고 그 블랙핑크 완전치 활동을 한다면은 올해보다 내년에 실적이 컨덤 점프를 할 수 있는 기업이라고 보시면 될 것 같습니다 어 팬심이 너무 마음에 와닿은 분석이었다 나왔습니다 법원에서 민희진어도 대표가 하이브를 상대로 제기한 가처분 신청을 인용하면서 어도어 대표직을 계속해서 유지하라고 밝혔는데요 어 내일장 또 하이브의 역할이 또 어떻게 반영될지 궁금해지는 포인트입니다 먼저 즈 엔터테인먼트 다시 좀 들어가 보자면네 베이비 몬스터와 블랙 피크라 노엔 텀이 있는데 목표가 손절가는 어디까지 볼까요 어 일단 지금 와이즈 엔터는 어 양연석 최대주주가 1월 달에 어 200억을 어 쐈어요 200원을 이제 들여 갖고 이제 주식을 매입을 했는데 그때 단가랑 현재가랑 비교 봤을 때 와이지엔터 어 수장인 양현석 대표도 지금 혼재 영현석 최대 주주도 많이 물려 있는 상황이긴 한데 어 1월 매수가는 비교해 봤을 때 근데 만약에이 기업이 만약에 이제 기술적으로 이제 반등이 나온다면 어 차 목표가는 47,500원 정도로 설정하시는게 이제 바람직해 보이고 그리고 만약에 주가 하락시 리스크 관리가 좀 필요하신 분들은 어 손절가를 4700원 정도로 어 설정하시면 될 거 같습니다 그리고 뭐 보니깐 와 그 양연석 그 총괄 프로듀서가 매입한 1월 달에 매입한 가격과 현재가가 괴리율이 크지 않으니까 약간 운명을 같이 할 수 있는 포지션을 구축할 수 있을 것 같습니다네 베이비 몬스터 기대감을 가진 와이즈 엔터테인먼트 목표가 47,500원 손절가 4700원 기억하겠습니다 여서 두 번째 이슈로 넘어가 보시죠 최근 반도체 공장 가동률이 평균 75% 기록하면서 회복세를 보이고 있습니다 이런 추세라면 또 하반기는 80%지도 좀 올라올 것으로 보이는데요 대표님 랜드 쪽도 좀 회복을 보일 수 있을까요 어 좋죠 그러니까 그 AI 반도체 그 가동률은 상당히 높은 수준이 지금 현재 유지가 되고 있고 레거시 반도체 그 생산 라인도 가동률이 하반기로 갈수록 이제 올라갈 가능성이 높아 보이고요 그리고 랜드 가동률이 지금 상당히 아직도 상당히 미흡하긴 하지 지만 하반기로 갈수록 기업용 SSD 수요가 증가하면서 가동률이 좀 고개를 들 가능성이 좀 높다라고 보시면 될 것 같습니다 특히 HB 같은 경우에는 이제 가동률이 7 80% 정도가 되지만 이제 하반기 때 더 올라갈 수 있는 그런 상황이라고 보시면 될 거 같고 그리고 반도체 패 가동률이 80% 이상으로 치고 나가면은 신규 장비 발주에 대한 기대감도 이제 부각될 수 있거든요 그래서 어 it 장비주도 투심이 이제 멀지는 미래에 개선이 될 것으로 기대가 되고 있습니다 어 그렇다면 그 안에서 어떤 종목 지금 볼까요 사실 반도체주들이 많이 내려와서 지금 또 관심 가져도 될까라는 좀 의문도 들거든요 어떤 종목이 좀 괜찮죠 그러니까 반도체 및 디스플레이 가동률이 하반기로 갈수록 우상을 때 수혜를 보는 대표적인 기업 그 기업은 바로 한솔 케미칼 있니다 한솔 케미칼은 현재 기술적 위치가 너무나도 겸손하고 상당히 저평가되어 있는 종목이라고 보시면 될 거 같아요 반도체 및 디스플레이 공정에 필요한 고순도 과산화 수소가 동사에 어 캐시 카우고 또 프리커서 사업을 영하고 있는데 프 커서는 삼성전자에 납품이 되고 있지만 되고 있고 tsmc 지금 납품이 되고 있기 때문에 삼성전자고덕산단 보시면 될 거 같고요 또 저가 원재료가 투입이 될 거 같아요 그래서 2분기 실적은 시장 예상치를 상회하게 될 가능성이 상당히 높아 보이고요 작년에 반도체 어항이 정말 안 좋았음에도 불구하고 영업 이익률 16% 그리고 RO 1를 13% 나 기록한 기업이니 올해 반도체 어항이 하반기로 가수로 좋아질 예정이니이 기업은 올해 Roe 어 그 영업 이익률이 전년 대비 상당히 인상적으로 어 점프할 수 있는 기업이라고 저는 보고 있습니다네 반도체 디스플레이 2차 전지 소재 다 가지고 있는데 좋다 좋다 하는데 주가는 안 좋아요 사실 목표가 순조가 어디까지 볼까요 어 좋다 좋다 하는데 주가가 바닥에 깔려 있기 때문에 제가 소개해 드리는 거겠죠 건방지기 올랐으면 저는 소개를 안 해 드리는 스타일인 거 이제 시청자분들이 명확하게 인지하고 계실 겁니다 자이 기업은  ...
#
# 🔷 영상 요약 전 후
# 어 주가터널과 한중일 정상회의를 계기로 엔터 콘텐츠 주들의 기대감이 커지고 있어 투자 전략이 세워지고 있습니다
